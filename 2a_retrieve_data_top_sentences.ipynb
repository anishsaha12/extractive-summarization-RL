# %%
from datasets import load_dataset, load_from_disk, Dataset
import numpy as np
import pandas as pd
from transformers import RobertaTokenizer, RobertaModel
import torch
import pickle
from torch.utils.data import TensorDataset, DataLoader

# %%
data_base = 'data'
dataset_name = 'cnn_dailymail'

data_path = data_base+'/'+dataset_name
sentence_emb_path = data_path+'/sentence_embs'

# %%
dataset = load_from_disk(
    data_path+'/sentences'
)

# %%
splits = ['train','test','validation']

a_id_len = dict([
    (s,dict()) for s in splits
])

for split in splits:
  cumu = 0
  for a_id, a_len in zip(dataset[split]['id'],dataset[split]['article_length']):
    a_id_len[split][a_id] = (a_len, cumu)
    cumu+=a_len   # cumulative sum -> num sentences upto before this article

with open(sentence_emb_path+'/articleID_sentences_info.pkl', 'wb') as pickle_file:
    pickle.dump(a_id_len, pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open(sentence_emb_path+'/articleID_sentences_info.pkl', "rb") as input_f:
    a_id_len = pickle.load(input_f)

def get_chunk_batch_sent_idx(split, a_id, a_s_idx): # data_split, article id, sentence idx within article
  num_s_per_chunk = 20000*40

  s_idx = a_id_len[split][a_id][1]+a_s_idx
  chunk_num = int(s_idx/num_s_per_chunk)+1
  batch_idx = int((s_idx%num_s_per_chunk)/40)
  batch_s_idx = (s_idx%num_s_per_chunk)%40

  return chunk_num, batch_idx, batch_s_idx

def get_article_sent_emb(split, chunk_num, batch_idx, batch_s_idx, sent_embs_chunk=None):
  if sent_embs_chunk==None:
      with open(
          sentence_emb_path+'/'+split+'/'+split+'_part_'+str(chunk_num)+".pkl", 
          "rb") as input_f:
        sent_embs_chunk = pickle.load(input_f)
  return sent_embs_chunk[batch_idx][batch_s_idx], sent_embs_chunk

# %%
# dataset = load_from_disk(
#     'data/cnn_dailymail/sentences/test/test_rewards'
# )

# %%
# dataset = load_from_disk(
#     'data/cnn_dailymail/sentences/validation/val_rewards'
# )

# %%
dataset = load_from_disk(
    'data/cnn_dailymail/sentences/train/train_rewards'
)

# %%
dataset
# Out:
# Dataset({
#     features: ['highlights', 'id', 'article_rouge_f1', 'article_top_sent', 'top_summaries', 'all_gold_actions', 'all_gold_rewards', 'top_full_sentences'],
#     num_rows: 11490
# })

# %%
# required_items = []
# for a_id, a_s_idx_list in zip(dataset['id'], dataset['article_top_sent']):
#     for a_s_idx in a_s_idx_list:
#         chunk_num, batch_idx, batch_s_idx = get_chunk_batch_sent_idx('test', a_id, a_s_idx)
#         required_items.append((chunk_num, batch_idx, batch_s_idx))

# %%
# required_items = []
# for a_id, a_s_idx_list in zip(dataset['id'], dataset['article_top_sent']):
#     for a_s_idx in a_s_idx_list:
#         chunk_num, batch_idx, batch_s_idx = get_chunk_batch_sent_idx('validation', a_id, a_s_idx)
#         required_items.append((chunk_num, batch_idx, batch_s_idx))

# %%
required_items = []
for a_id, a_s_idx_list in zip(dataset['article_id']['article_id'], dataset['top_sentences_index']['top_sentences_index']):
    for a_s_idx in a_s_idx_list:
        chunk_num, batch_idx, batch_s_idx = get_chunk_batch_sent_idx('train', a_id, a_s_idx)
        required_items.append((chunk_num, batch_idx, batch_s_idx))

# %%
len(required_items)
# Out:
# 114386

# %%
loaded_current_chunk = None
sent_embs_chunk = None
res = []

# %%
# for i,(chunk_num, batch_idx, batch_s_idx) in enumerate(required_items):
# #     if i<=(2053602-1):
# #         res.append(None)
# #     else:
#         if loaded_current_chunk==chunk_num:
#             s_emb, sent_embs_chunk = get_article_sent_emb(
#                 'test', chunk_num, batch_idx, batch_s_idx, sent_embs_chunk
#             )
#             res.append(s_emb)
#         else:
#             print('  Loading chunk:', chunk_num)
#             loaded_current_chunk = chunk_num
#             s_emb, sent_embs_chunk = get_article_sent_emb(
#                 'test', chunk_num, batch_idx, batch_s_idx, None
#             )
#             res.append(s_emb)
#         if i%500==0:
#             print('Loaded',i+1,'embs of',len(required_items))
# Out:
#   Loading chunk: 1
# Loaded 1 embs of 114386
# Loaded 501 embs of 114386
# Loaded 1001 embs of 114386
# Loaded 1501 embs of 114386
# Loaded 2001 embs of 114386
# Loaded 2501 embs of 114386
# Loaded 3001 embs of 114386
# Loaded 3501 embs of 114386
# Loaded 4001 embs of 114386
# Loaded 4501 embs of 114386
# Loaded 5001 embs of 114386
# Loaded 5501 embs of 114386
# Loaded 6001 embs of 114386
# Loaded 6501 embs of 114386
# Loaded 7001 embs of 114386
# Loaded 7501 embs of 114386
# Loaded 8001 embs of 114386
# Loaded 8501 embs of 114386
# Loaded 9001 embs of 114386
# Loaded 9501 embs of 114386
# Loaded 10001 embs of 114386
# Loaded 10501 embs of 114386
# Loaded 11001 embs of 114386
# Loaded 11501 embs of 114386
# Loaded 12001 embs of 114386
# Loaded 12501 embs of 114386
# Loaded 13001 embs of 114386
# Loaded 13501 embs of 114386
# Loaded 14001 embs of 114386
# Loaded 14501 embs of 114386
# Loaded 15001 embs of 114386
# Loaded 15501 embs of 114386
# Loaded 16001 embs of 114386
# Loaded 16501 embs of 114386
# Loaded 17001 embs of 114386
# Loaded 17501 embs of 114386
# Loaded 18001 embs of 114386
# Loaded 18501 embs of 114386
# Loaded 19001 embs of 114386
# Loaded 19501 embs of 114386
# Loaded 20001 embs of 114386
# Loaded 20501 embs of 114386
# Loaded 21001 embs of 114386
# Loaded 21501 embs of 114386
# Loaded 22001 embs of 114386
# Loaded 22501 embs of 114386
# Loaded 23001 embs of 114386
# Loaded 23501 embs of 114386
# Loaded 24001 embs of 114386
# Loaded 24501 embs of 114386
# Loaded 25001 embs of 114386
# Loaded 25501 embs of 114386
# Loaded 26001 embs of 114386
# Loaded 26501 embs of 114386
# Loaded 27001 embs of 114386
# Loaded 27501 embs of 114386
# Loaded 28001 embs of 114386
# Loaded 28501 embs of 114386
# Loaded 29001 embs of 114386
# Loaded 29501 embs of 114386
# Loaded 30001 embs of 114386
# Loaded 30501 embs of 114386
# Loaded 31001 embs of 114386
# Loaded 31501 embs of 114386
# Loaded 32001 embs of 114386
# Loaded 32501 embs of 114386
# Loaded 33001 embs of 114386
# Loaded 33501 embs of 114386
# Loaded 34001 embs of 114386
# Loaded 34501 embs of 114386
# Loaded 35001 embs of 114386
# Loaded 35501 embs of 114386
# Loaded 36001 embs of 114386
# Loaded 36501 embs of 114386
# Loaded 37001 embs of 114386
# Loaded 37501 embs of 114386
# Loaded 38001 embs of 114386
# Loaded 38501 embs of 114386
# Loaded 39001 embs of 114386
# Loaded 39501 embs of 114386
# Loaded 40001 embs of 114386
# Loaded 40501 embs of 114386
# Loaded 41001 embs of 114386
# Loaded 41501 embs of 114386
# Loaded 42001 embs of 114386
# Loaded 42501 embs of 114386
# Loaded 43001 embs of 114386
# Loaded 43501 embs of 114386
# Loaded 44001 embs of 114386
# Loaded 44501 embs of 114386
# Loaded 45001 embs of 114386
# Loaded 45501 embs of 114386
# Loaded 46001 embs of 114386
# Loaded 46501 embs of 114386
# Loaded 47001 embs of 114386
# Loaded 47501 embs of 114386
# Loaded 48001 embs of 114386
# Loaded 48501 embs of 114386
# Loaded 49001 embs of 114386
# Loaded 49501 embs of 114386
# Loaded 50001 embs of 114386
# Loaded 50501 embs of 114386
# Loaded 51001 embs of 114386
# Loaded 51501 embs of 114386
# Loaded 52001 embs of 114386
# Loaded 52501 embs of 114386
# Loaded 53001 embs of 114386
# Loaded 53501 embs of 114386
# Loaded 54001 embs of 114386
# Loaded 54501 embs of 114386
# Loaded 55001 embs of 114386
# Loaded 55501 embs of 114386
# Loaded 56001 embs of 114386
# Loaded 56501 embs of 114386
# Loaded 57001 embs of 114386
# Loaded 57501 embs of 114386
# Loaded 58001 embs of 114386
# Loaded 58501 embs of 114386
# Loaded 59001 embs of 114386
# Loaded 59501 embs of 114386
# Loaded 60001 embs of 114386
# Loaded 60501 embs of 114386
# Loaded 61001 embs of 114386
# Loaded 61501 embs of 114386
# Loaded 62001 embs of 114386
# Loaded 62501 embs of 114386
# Loaded 63001 embs of 114386
# Loaded 63501 embs of 114386
# Loaded 64001 embs of 114386
# Loaded 64501 embs of 114386
# Loaded 65001 embs of 114386
# Loaded 65501 embs of 114386
# Loaded 66001 embs of 114386
# Loaded 66501 embs of 114386
# Loaded 67001 embs of 114386
# Loaded 67501 embs of 114386
# Loaded 68001 embs of 114386
# Loaded 68501 embs of 114386
# Loaded 69001 embs of 114386
# Loaded 69501 embs of 114386
# Loaded 70001 embs of 114386
# Loaded 70501 embs of 114386
# Loaded 71001 embs of 114386
# Loaded 71501 embs of 114386
# Loaded 72001 embs of 114386
# Loaded 72501 embs of 114386
# Loaded 73001 embs of 114386
# Loaded 73501 embs of 114386
# Loaded 74001 embs of 114386
# Loaded 74501 embs of 114386
# Loaded 75001 embs of 114386
# Loaded 75501 embs of 114386
# Loaded 76001 embs of 114386
# Loaded 76501 embs of 114386
# Loaded 77001 embs of 114386
# Loaded 77501 embs of 114386
# Loaded 78001 embs of 114386
# Loaded 78501 embs of 114386
# Loaded 79001 embs of 114386
# Loaded 79501 embs of 114386
# Loaded 80001 embs of 114386
# Loaded 80501 embs of 114386
# Loaded 81001 embs of 114386
# Loaded 81501 embs of 114386
# Loaded 82001 embs of 114386
# Loaded 82501 embs of 114386
# Loaded 83001 embs of 114386
# Loaded 83501 embs of 114386
# Loaded 84001 embs of 114386
# Loaded 84501 embs of 114386
# Loaded 85001 embs of 114386
# Loaded 85501 embs of 114386
# Loaded 86001 embs of 114386
# Loaded 86501 embs of 114386
# Loaded 87001 embs of 114386
# Loaded 87501 embs of 114386
# Loaded 88001 embs of 114386
# Loaded 88501 embs of 114386
# Loaded 89001 embs of 114386
# Loaded 89501 embs of 114386
# Loaded 90001 embs of 114386
# Loaded 90501 embs of 114386
# Loaded 91001 embs of 114386
# Loaded 91501 embs of 114386
# Loaded 92001 embs of 114386
# Loaded 92501 embs of 114386
# Loaded 93001 embs of 114386
# Loaded 93501 embs of 114386
# Loaded 94001 embs of 114386
# Loaded 94501 embs of 114386
# Loaded 95001 embs of 114386
# Loaded 95501 embs of 114386
# Loaded 96001 embs of 114386
# Loaded 96501 embs of 114386
# Loaded 97001 embs of 114386
# Loaded 97501 embs of 114386
# Loaded 98001 embs of 114386
# Loaded 98501 embs of 114386
# Loaded 99001 embs of 114386
# Loaded 99501 embs of 114386
# Loaded 100001 embs of 114386
# Loaded 100501 embs of 114386
# Loaded 101001 embs of 114386
# Loaded 101501 embs of 114386
# Loaded 102001 embs of 114386
# Loaded 102501 embs of 114386
# Loaded 103001 embs of 114386
# Loaded 103501 embs of 114386
# Loaded 104001 embs of 114386
# Loaded 104501 embs of 114386
# Loaded 105001 embs of 114386
# Loaded 105501 embs of 114386
# Loaded 106001 embs of 114386
# Loaded 106501 embs of 114386
# Loaded 107001 embs of 114386
# Loaded 107501 embs of 114386
# Loaded 108001 embs of 114386
# Loaded 108501 embs of 114386
# Loaded 109001 embs of 114386
# Loaded 109501 embs of 114386
# Loaded 110001 embs of 114386
# Loaded 110501 embs of 114386
# Loaded 111001 embs of 114386
# Loaded 111501 embs of 114386
# Loaded 112001 embs of 114386
# Loaded 112501 embs of 114386
# Loaded 113001 embs of 114386
# Loaded 113501 embs of 114386
# Loaded 114001 embs of 114386

# %%
# for i,(chunk_num, batch_idx, batch_s_idx) in enumerate(required_items):
# #     if i<=(2053602-1):
# #         res.append(None)
# #     else:
#         if loaded_current_chunk==chunk_num:
#             s_emb, sent_embs_chunk = get_article_sent_emb(
#                 'validation', chunk_num, batch_idx, batch_s_idx, sent_embs_chunk
#             )
#             res.append(s_emb)
#         else:
#             print('  Loading chunk:', chunk_num)
#             loaded_current_chunk = chunk_num
#             s_emb, sent_embs_chunk = get_article_sent_emb(
#                 'validation', chunk_num, batch_idx, batch_s_idx, None
#             )
#             res.append(s_emb)
#         if i%500==0:
#             print('Loaded',i+1,'embs of',len(required_items))
# Out:
#   Loading chunk: 1
# Loaded 1 embs of 133144
# Loaded 501 embs of 133144
# Loaded 1001 embs of 133144
# Loaded 1501 embs of 133144
# Loaded 2001 embs of 133144
# Loaded 2501 embs of 133144
# Loaded 3001 embs of 133144
# Loaded 3501 embs of 133144
# Loaded 4001 embs of 133144
# Loaded 4501 embs of 133144
# Loaded 5001 embs of 133144
# Loaded 5501 embs of 133144
# Loaded 6001 embs of 133144
# Loaded 6501 embs of 133144
# Loaded 7001 embs of 133144
# Loaded 7501 embs of 133144
# Loaded 8001 embs of 133144
# Loaded 8501 embs of 133144
# Loaded 9001 embs of 133144
# Loaded 9501 embs of 133144
# Loaded 10001 embs of 133144
# Loaded 10501 embs of 133144
# Loaded 11001 embs of 133144
# Loaded 11501 embs of 133144
# Loaded 12001 embs of 133144
# Loaded 12501 embs of 133144
# Loaded 13001 embs of 133144
# Loaded 13501 embs of 133144
# Loaded 14001 embs of 133144
# Loaded 14501 embs of 133144
# Loaded 15001 embs of 133144
# Loaded 15501 embs of 133144
# Loaded 16001 embs of 133144
# Loaded 16501 embs of 133144
# Loaded 17001 embs of 133144
# Loaded 17501 embs of 133144
# Loaded 18001 embs of 133144
# Loaded 18501 embs of 133144
# Loaded 19001 embs of 133144
# Loaded 19501 embs of 133144
# Loaded 20001 embs of 133144
# Loaded 20501 embs of 133144
# Loaded 21001 embs of 133144
# Loaded 21501 embs of 133144
# Loaded 22001 embs of 133144
# Loaded 22501 embs of 133144
# Loaded 23001 embs of 133144
# Loaded 23501 embs of 133144
# Loaded 24001 embs of 133144
# Loaded 24501 embs of 133144
# Loaded 25001 embs of 133144
# Loaded 25501 embs of 133144
# Loaded 26001 embs of 133144
# Loaded 26501 embs of 133144
# Loaded 27001 embs of 133144
# Loaded 27501 embs of 133144
# Loaded 28001 embs of 133144
# Loaded 28501 embs of 133144
# Loaded 29001 embs of 133144
# Loaded 29501 embs of 133144
# Loaded 30001 embs of 133144
# Loaded 30501 embs of 133144
# Loaded 31001 embs of 133144
# Loaded 31501 embs of 133144
# Loaded 32001 embs of 133144
# Loaded 32501 embs of 133144
# Loaded 33001 embs of 133144
# Loaded 33501 embs of 133144
# Loaded 34001 embs of 133144
# Loaded 34501 embs of 133144
# Loaded 35001 embs of 133144
# Loaded 35501 embs of 133144
# Loaded 36001 embs of 133144
# Loaded 36501 embs of 133144
# Loaded 37001 embs of 133144
# Loaded 37501 embs of 133144
# Loaded 38001 embs of 133144
# Loaded 38501 embs of 133144
# Loaded 39001 embs of 133144
# Loaded 39501 embs of 133144
# Loaded 40001 embs of 133144
# Loaded 40501 embs of 133144
# Loaded 41001 embs of 133144
# Loaded 41501 embs of 133144
# Loaded 42001 embs of 133144
# Loaded 42501 embs of 133144
# Loaded 43001 embs of 133144
# Loaded 43501 embs of 133144
# Loaded 44001 embs of 133144
# Loaded 44501 embs of 133144
# Loaded 45001 embs of 133144
# Loaded 45501 embs of 133144
# Loaded 46001 embs of 133144
# Loaded 46501 embs of 133144
# Loaded 47001 embs of 133144
# Loaded 47501 embs of 133144
# Loaded 48001 embs of 133144
# Loaded 48501 embs of 133144
# Loaded 49001 embs of 133144
# Loaded 49501 embs of 133144
# Loaded 50001 embs of 133144
# Loaded 50501 embs of 133144
# Loaded 51001 embs of 133144
# Loaded 51501 embs of 133144
# Loaded 52001 embs of 133144
# Loaded 52501 embs of 133144
# Loaded 53001 embs of 133144
# Loaded 53501 embs of 133144
# Loaded 54001 embs of 133144
# Loaded 54501 embs of 133144
# Loaded 55001 embs of 133144
# Loaded 55501 embs of 133144
# Loaded 56001 embs of 133144
# Loaded 56501 embs of 133144
# Loaded 57001 embs of 133144
# Loaded 57501 embs of 133144
# Loaded 58001 embs of 133144
# Loaded 58501 embs of 133144
# Loaded 59001 embs of 133144
# Loaded 59501 embs of 133144
# Loaded 60001 embs of 133144
# Loaded 60501 embs of 133144
# Loaded 61001 embs of 133144
# Loaded 61501 embs of 133144
# Loaded 62001 embs of 133144
# Loaded 62501 embs of 133144
# Loaded 63001 embs of 133144
# Loaded 63501 embs of 133144
# Loaded 64001 embs of 133144
# Loaded 64501 embs of 133144
# Loaded 65001 embs of 133144
# Loaded 65501 embs of 133144
# Loaded 66001 embs of 133144
# Loaded 66501 embs of 133144
# Loaded 67001 embs of 133144
# Loaded 67501 embs of 133144
# Loaded 68001 embs of 133144
# Loaded 68501 embs of 133144
# Loaded 69001 embs of 133144
# Loaded 69501 embs of 133144
# Loaded 70001 embs of 133144
# Loaded 70501 embs of 133144
# Loaded 71001 embs of 133144
# Loaded 71501 embs of 133144
# Loaded 72001 embs of 133144
# Loaded 72501 embs of 133144
# Loaded 73001 embs of 133144
# Loaded 73501 embs of 133144
# Loaded 74001 embs of 133144
# Loaded 74501 embs of 133144
# Loaded 75001 embs of 133144
# Loaded 75501 embs of 133144
# Loaded 76001 embs of 133144
# Loaded 76501 embs of 133144
# Loaded 77001 embs of 133144
# Loaded 77501 embs of 133144
# Loaded 78001 embs of 133144
# Loaded 78501 embs of 133144
# Loaded 79001 embs of 133144
# Loaded 79501 embs of 133144
# Loaded 80001 embs of 133144
# Loaded 80501 embs of 133144
# Loaded 81001 embs of 133144
# Loaded 81501 embs of 133144
# Loaded 82001 embs of 133144
# Loaded 82501 embs of 133144
# Loaded 83001 embs of 133144
# Loaded 83501 embs of 133144
# Loaded 84001 embs of 133144
# Loaded 84501 embs of 133144
# Loaded 85001 embs of 133144
# Loaded 85501 embs of 133144
# Loaded 86001 embs of 133144
# Loaded 86501 embs of 133144
# Loaded 87001 embs of 133144
# Loaded 87501 embs of 133144
# Loaded 88001 embs of 133144
# Loaded 88501 embs of 133144
# Loaded 89001 embs of 133144
# Loaded 89501 embs of 133144
# Loaded 90001 embs of 133144
# Loaded 90501 embs of 133144
# Loaded 91001 embs of 133144
# Loaded 91501 embs of 133144
# Loaded 92001 embs of 133144
# Loaded 92501 embs of 133144
# Loaded 93001 embs of 133144
# Loaded 93501 embs of 133144
# Loaded 94001 embs of 133144
# Loaded 94501 embs of 133144
# Loaded 95001 embs of 133144
# Loaded 95501 embs of 133144
# Loaded 96001 embs of 133144
# Loaded 96501 embs of 133144
# Loaded 97001 embs of 133144
# Loaded 97501 embs of 133144
# Loaded 98001 embs of 133144
# Loaded 98501 embs of 133144
# Loaded 99001 embs of 133144
# Loaded 99501 embs of 133144
# Loaded 100001 embs of 133144
# Loaded 100501 embs of 133144
# Loaded 101001 embs of 133144
# Loaded 101501 embs of 133144
# Loaded 102001 embs of 133144
# Loaded 102501 embs of 133144
# Loaded 103001 embs of 133144
# Loaded 103501 embs of 133144
# Loaded 104001 embs of 133144
# Loaded 104501 embs of 133144
# Loaded 105001 embs of 133144
# Loaded 105501 embs of 133144
# Loaded 106001 embs of 133144
# Loaded 106501 embs of 133144
# Loaded 107001 embs of 133144
# Loaded 107501 embs of 133144
# Loaded 108001 embs of 133144
# Loaded 108501 embs of 133144
# Loaded 109001 embs of 133144
# Loaded 109501 embs of 133144
# Loaded 110001 embs of 133144
# Loaded 110501 embs of 133144
# Loaded 111001 embs of 133144
# Loaded 111501 embs of 133144
# Loaded 112001 embs of 133144
# Loaded 112501 embs of 133144
# Loaded 113001 embs of 133144
# Loaded 113501 embs of 133144
# Loaded 114001 embs of 133144
# Loaded 114501 embs of 133144
# Loaded 115001 embs of 133144
# Loaded 115501 embs of 133144
# Loaded 116001 embs of 133144
# Loaded 116501 embs of 133144
# Loaded 117001 embs of 133144
# Loaded 117501 embs of 133144
# Loaded 118001 embs of 133144
# Loaded 118501 embs of 133144
# Loaded 119001 embs of 133144
# Loaded 119501 embs of 133144
# Loaded 120001 embs of 133144
# Loaded 120501 embs of 133144
# Loaded 121001 embs of 133144
# Loaded 121501 embs of 133144
# Loaded 122001 embs of 133144
# Loaded 122501 embs of 133144
# Loaded 123001 embs of 133144
# Loaded 123501 embs of 133144
# Loaded 124001 embs of 133144
# Loaded 124501 embs of 133144
# Loaded 125001 embs of 133144
# Loaded 125501 embs of 133144
# Loaded 126001 embs of 133144
# Loaded 126501 embs of 133144
# Loaded 127001 embs of 133144
# Loaded 127501 embs of 133144
# Loaded 128001 embs of 133144
# Loaded 128501 embs of 133144
# Loaded 129001 embs of 133144
# Loaded 129501 embs of 133144
# Loaded 130001 embs of 133144
# Loaded 130501 embs of 133144
# Loaded 131001 embs of 133144
# Loaded 131501 embs of 133144
# Loaded 132001 embs of 133144
# Loaded 132501 embs of 133144
# Loaded 133001 embs of 133144

# %%
for i,(chunk_num, batch_idx, batch_s_idx) in enumerate(required_items):
    if i<=(2053602-1):
        res.append(None)
    else:
        if loaded_current_chunk==chunk_num:
            s_emb, sent_embs_chunk = get_article_sent_emb(
                'train', chunk_num, batch_idx, batch_s_idx, sent_embs_chunk
            )
            res.append(s_emb)
        else:
            print('  Loading chunk:', chunk_num)
            loaded_current_chunk = chunk_num
            s_emb, sent_embs_chunk = get_article_sent_emb(
                'train', chunk_num, batch_idx, batch_s_idx, None
            )
            res.append(s_emb)
        if i%500==0:
            print('Loaded',i+1,'embs of',len(required_items))
# Out:
#   Loading chunk: 11
# Loaded 2054001 embs of 2860802
# Loaded 2054501 embs of 2860802
# Loaded 2055001 embs of 2860802
# Loaded 2055501 embs of 2860802
# Loaded 2056001 embs of 2860802
# Loaded 2056501 embs of 2860802
# Loaded 2057001 embs of 2860802
# Loaded 2057501 embs of 2860802
# Loaded 2058001 embs of 2860802
# Loaded 2058501 embs of 2860802
# Loaded 2059001 embs of 2860802
# Loaded 2059501 embs of 2860802
# Loaded 2060001 embs of 2860802
# Loaded 2060501 embs of 2860802
# Loaded 2061001 embs of 2860802
# Loaded 2061501 embs of 2860802
# Loaded 2062001 embs of 2860802
# Loaded 2062501 embs of 2860802
# Loaded 2063001 embs of 2860802
# Loaded 2063501 embs of 2860802
# Loaded 2064001 embs of 2860802
# Loaded 2064501 embs of 2860802
# Loaded 2065001 embs of 2860802
# Loaded 2065501 embs of 2860802
# Loaded 2066001 embs of 2860802
# Loaded 2066501 embs of 2860802
# Loaded 2067001 embs of 2860802
# Loaded 2067501 embs of 2860802
# Loaded 2068001 embs of 2860802
# Loaded 2068501 embs of 2860802
# Loaded 2069001 embs of 2860802
# Loaded 2069501 embs of 2860802
# Loaded 2070001 embs of 2860802
# Loaded 2070501 embs of 2860802
# Loaded 2071001 embs of 2860802
# Loaded 2071501 embs of 2860802
# Loaded 2072001 embs of 2860802
# Loaded 2072501 embs of 2860802
# Loaded 2073001 embs of 2860802
# Loaded 2073501 embs of 2860802
# Loaded 2074001 embs of 2860802
# Loaded 2074501 embs of 2860802
# Loaded 2075001 embs of 2860802
# Loaded 2075501 embs of 2860802
# Loaded 2076001 embs of 2860802
# Loaded 2076501 embs of 2860802
# Loaded 2077001 embs of 2860802
# Loaded 2077501 embs of 2860802
# Loaded 2078001 embs of 2860802
# Loaded 2078501 embs of 2860802
# Loaded 2079001 embs of 2860802
# Loaded 2079501 embs of 2860802
# Loaded 2080001 embs of 2860802
# Loaded 2080501 embs of 2860802
# Loaded 2081001 embs of 2860802
# Loaded 2081501 embs of 2860802
# Loaded 2082001 embs of 2860802
# Loaded 2082501 embs of 2860802
# Loaded 2083001 embs of 2860802
# Loaded 2083501 embs of 2860802
# Loaded 2084001 embs of 2860802
# Loaded 2084501 embs of 2860802
# Loaded 2085001 embs of 2860802
# Loaded 2085501 embs of 2860802
# Loaded 2086001 embs of 2860802
# Loaded 2086501 embs of 2860802
# Loaded 2087001 embs of 2860802
# Loaded 2087501 embs of 2860802
# Loaded 2088001 embs of 2860802
# Loaded 2088501 embs of 2860802
# Loaded 2089001 embs of 2860802
# Loaded 2089501 embs of 2860802
# Loaded 2090001 embs of 2860802
# Loaded 2090501 embs of 2860802
# Loaded 2091001 embs of 2860802
# Loaded 2091501 embs of 2860802
# Loaded 2092001 embs of 2860802
# Loaded 2092501 embs of 2860802
# Loaded 2093001 embs of 2860802
# Loaded 2093501 embs of 2860802
# Loaded 2094001 embs of 2860802
# Loaded 2094501 embs of 2860802
# Loaded 2095001 embs of 2860802
# Loaded 2095501 embs of 2860802
# Loaded 2096001 embs of 2860802
# Loaded 2096501 embs of 2860802
# Loaded 2097001 embs of 2860802
# Loaded 2097501 embs of 2860802
# Loaded 2098001 embs of 2860802
# Loaded 2098501 embs of 2860802
# Loaded 2099001 embs of 2860802
# Loaded 2099501 embs of 2860802
# Loaded 2100001 embs of 2860802
# Loaded 2100501 embs of 2860802
# Loaded 2101001 embs of 2860802
# Loaded 2101501 embs of 2860802
# Loaded 2102001 embs of 2860802
# Loaded 2102501 embs of 2860802
# Loaded 2103001 embs of 2860802
# Loaded 2103501 embs of 2860802
# Loaded 2104001 embs of 2860802
# Loaded 2104501 embs of 2860802
# Loaded 2105001 embs of 2860802
# Loaded 2105501 embs of 2860802
# Loaded 2106001 embs of 2860802
# Loaded 2106501 embs of 2860802
# Loaded 2107001 embs of 2860802
# Loaded 2107501 embs of 2860802
# Loaded 2108001 embs of 2860802
# Loaded 2108501 embs of 2860802
# Loaded 2109001 embs of 2860802
# Loaded 2109501 embs of 2860802
# Loaded 2110001 embs of 2860802
# Loaded 2110501 embs of 2860802
# Loaded 2111001 embs of 2860802
# Loaded 2111501 embs of 2860802
# Loaded 2112001 embs of 2860802
# Loaded 2112501 embs of 2860802
# Loaded 2113001 embs of 2860802
# Loaded 2113501 embs of 2860802
# Loaded 2114001 embs of 2860802
# Loaded 2114501 embs of 2860802
# Loaded 2115001 embs of 2860802
# Loaded 2115501 embs of 2860802
# Loaded 2116001 embs of 2860802
# Loaded 2116501 embs of 2860802
# Loaded 2117001 embs of 2860802
# Loaded 2117501 embs of 2860802
# Loaded 2118001 embs of 2860802
# Loaded 2118501 embs of 2860802
# Loaded 2119001 embs of 2860802
# Loaded 2119501 embs of 2860802
# Loaded 2120001 embs of 2860802
# Loaded 2120501 embs of 2860802
# Loaded 2121001 embs of 2860802
# Loaded 2121501 embs of 2860802
# Loaded 2122001 embs of 2860802
# Loaded 2122501 embs of 2860802
# Loaded 2123001 embs of 2860802
# Loaded 2123501 embs of 2860802
# Loaded 2124001 embs of 2860802
# Loaded 2124501 embs of 2860802
# Loaded 2125001 embs of 2860802
# Loaded 2125501 embs of 2860802
# Loaded 2126001 embs of 2860802
# Loaded 2126501 embs of 2860802
# Loaded 2127001 embs of 2860802
# Loaded 2127501 embs of 2860802
# Loaded 2128001 embs of 2860802
# Loaded 2128501 embs of 2860802
# Loaded 2129001 embs of 2860802
# Loaded 2129501 embs of 2860802
# Loaded 2130001 embs of 2860802
# Loaded 2130501 embs of 2860802
# Loaded 2131001 embs of 2860802
# Loaded 2131501 embs of 2860802
# Loaded 2132001 embs of 2860802
# Loaded 2132501 embs of 2860802
# Loaded 2133001 embs of 2860802
# Loaded 2133501 embs of 2860802
# Loaded 2134001 embs of 2860802
# Loaded 2134501 embs of 2860802
# Loaded 2135001 embs of 2860802
# Loaded 2135501 embs of 2860802
# Loaded 2136001 embs of 2860802
# Loaded 2136501 embs of 2860802
# Loaded 2137001 embs of 2860802
# Loaded 2137501 embs of 2860802
# Loaded 2138001 embs of 2860802
# Loaded 2138501 embs of 2860802
# Loaded 2139001 embs of 2860802
# Loaded 2139501 embs of 2860802
# Loaded 2140001 embs of 2860802
# Loaded 2140501 embs of 2860802
# Loaded 2141001 embs of 2860802
# Loaded 2141501 embs of 2860802
# Loaded 2142001 embs of 2860802
# Loaded 2142501 embs of 2860802
# Loaded 2143001 embs of 2860802
# Loaded 2143501 embs of 2860802
# Loaded 2144001 embs of 2860802
# Loaded 2144501 embs of 2860802
# Loaded 2145001 embs of 2860802
# Loaded 2145501 embs of 2860802
# Loaded 2146001 embs of 2860802
# Loaded 2146501 embs of 2860802
# Loaded 2147001 embs of 2860802
# Loaded 2147501 embs of 2860802
# Loaded 2148001 embs of 2860802
# Loaded 2148501 embs of 2860802
# Loaded 2149001 embs of 2860802
# Loaded 2149501 embs of 2860802
# Loaded 2150001 embs of 2860802
# Loaded 2150501 embs of 2860802
# Loaded 2151001 embs of 2860802
# Loaded 2151501 embs of 2860802
# Loaded 2152001 embs of 2860802
# Loaded 2152501 embs of 2860802
# Loaded 2153001 embs of 2860802
# Loaded 2153501 embs of 2860802
# Loaded 2154001 embs of 2860802
# Loaded 2154501 embs of 2860802
# Loaded 2155001 embs of 2860802
# Loaded 2155501 embs of 2860802
# Loaded 2156001 embs of 2860802
# Loaded 2156501 embs of 2860802
# Loaded 2157001 embs of 2860802
# Loaded 2157501 embs of 2860802
# Loaded 2158001 embs of 2860802
# Loaded 2158501 embs of 2860802
# Loaded 2159001 embs of 2860802
# Loaded 2159501 embs of 2860802
# Loaded 2160001 embs of 2860802
# Loaded 2160501 embs of 2860802
# Loaded 2161001 embs of 2860802
# Loaded 2161501 embs of 2860802
# Loaded 2162001 embs of 2860802
# Loaded 2162501 embs of 2860802
# Loaded 2163001 embs of 2860802
# Loaded 2163501 embs of 2860802
# Loaded 2164001 embs of 2860802
# Loaded 2164501 embs of 2860802
# Loaded 2165001 embs of 2860802
# Loaded 2165501 embs of 2860802
# Loaded 2166001 embs of 2860802
# Loaded 2166501 embs of 2860802
# Loaded 2167001 embs of 2860802
# Loaded 2167501 embs of 2860802
# Loaded 2168001 embs of 2860802
# Loaded 2168501 embs of 2860802
# Loaded 2169001 embs of 2860802
# Loaded 2169501 embs of 2860802
# Loaded 2170001 embs of 2860802
# Loaded 2170501 embs of 2860802
# Loaded 2171001 embs of 2860802
# Loaded 2171501 embs of 2860802
# Loaded 2172001 embs of 2860802
# Loaded 2172501 embs of 2860802
# Loaded 2173001 embs of 2860802
# Loaded 2173501 embs of 2860802
# Loaded 2174001 embs of 2860802
# Loaded 2174501 embs of 2860802
# Loaded 2175001 embs of 2860802
# Loaded 2175501 embs of 2860802
# Loaded 2176001 embs of 2860802
# Loaded 2176501 embs of 2860802
# Loaded 2177001 embs of 2860802
# Loaded 2177501 embs of 2860802
# Loaded 2178001 embs of 2860802
# Loaded 2178501 embs of 2860802
# Loaded 2179001 embs of 2860802
# Loaded 2179501 embs of 2860802
# Loaded 2180001 embs of 2860802
# Loaded 2180501 embs of 2860802
# Loaded 2181001 embs of 2860802
# Loaded 2181501 embs of 2860802
# Loaded 2182001 embs of 2860802
# Loaded 2182501 embs of 2860802
# Loaded 2183001 embs of 2860802
# Loaded 2183501 embs of 2860802
# Loaded 2184001 embs of 2860802
# Loaded 2184501 embs of 2860802
# Loaded 2185001 embs of 2860802
# Loaded 2185501 embs of 2860802
# Loaded 2186001 embs of 2860802
# Loaded 2186501 embs of 2860802
# Loaded 2187001 embs of 2860802
# Loaded 2187501 embs of 2860802
# Loaded 2188001 embs of 2860802
# Loaded 2188501 embs of 2860802
# Loaded 2189001 embs of 2860802
# Loaded 2189501 embs of 2860802
# Loaded 2190001 embs of 2860802
# Loaded 2190501 embs of 2860802
# Loaded 2191001 embs of 2860802
# Loaded 2191501 embs of 2860802
# Loaded 2192001 embs of 2860802
# Loaded 2192501 embs of 2860802
# Loaded 2193001 embs of 2860802
# Loaded 2193501 embs of 2860802
# Loaded 2194001 embs of 2860802
# Loaded 2194501 embs of 2860802
# Loaded 2195001 embs of 2860802
# Loaded 2195501 embs of 2860802
# Loaded 2196001 embs of 2860802
# Loaded 2196501 embs of 2860802
# Loaded 2197001 embs of 2860802
# Loaded 2197501 embs of 2860802
# Loaded 2198001 embs of 2860802
# Loaded 2198501 embs of 2860802
# Loaded 2199001 embs of 2860802
# Loaded 2199501 embs of 2860802
# Loaded 2200001 embs of 2860802
# Loaded 2200501 embs of 2860802
# Loaded 2201001 embs of 2860802
# Loaded 2201501 embs of 2860802
# Loaded 2202001 embs of 2860802
# Loaded 2202501 embs of 2860802
# Loaded 2203001 embs of 2860802
# Loaded 2203501 embs of 2860802
# Loaded 2204001 embs of 2860802
# Loaded 2204501 embs of 2860802
# Loaded 2205001 embs of 2860802
# Loaded 2205501 embs of 2860802
# Loaded 2206001 embs of 2860802
# Loaded 2206501 embs of 2860802
# Loaded 2207001 embs of 2860802
# Loaded 2207501 embs of 2860802
# Loaded 2208001 embs of 2860802
# Loaded 2208501 embs of 2860802
# Loaded 2209001 embs of 2860802
# Loaded 2209501 embs of 2860802
# Loaded 2210001 embs of 2860802
# Loaded 2210501 embs of 2860802
# Loaded 2211001 embs of 2860802
# Loaded 2211501 embs of 2860802
# Loaded 2212001 embs of 2860802
# Loaded 2212501 embs of 2860802
# Loaded 2213001 embs of 2860802
# Loaded 2213501 embs of 2860802
# Loaded 2214001 embs of 2860802
# Loaded 2214501 embs of 2860802
# Loaded 2215001 embs of 2860802
# Loaded 2215501 embs of 2860802
# Loaded 2216001 embs of 2860802
# Loaded 2216501 embs of 2860802
# Loaded 2217001 embs of 2860802
# Loaded 2217501 embs of 2860802
# Loaded 2218001 embs of 2860802
# Loaded 2218501 embs of 2860802
# Loaded 2219001 embs of 2860802
# Loaded 2219501 embs of 2860802
# Loaded 2220001 embs of 2860802
# Loaded 2220501 embs of 2860802
# Loaded 2221001 embs of 2860802
# Loaded 2221501 embs of 2860802
# Loaded 2222001 embs of 2860802
# Loaded 2222501 embs of 2860802
# Loaded 2223001 embs of 2860802
# Loaded 2223501 embs of 2860802
# Loaded 2224001 embs of 2860802
# Loaded 2224501 embs of 2860802
# Loaded 2225001 embs of 2860802
# Loaded 2225501 embs of 2860802
# Loaded 2226001 embs of 2860802
# Loaded 2226501 embs of 2860802
# Loaded 2227001 embs of 2860802
# Loaded 2227501 embs of 2860802
# Loaded 2228001 embs of 2860802
# Loaded 2228501 embs of 2860802
# Loaded 2229001 embs of 2860802
# Loaded 2229501 embs of 2860802
# Loaded 2230001 embs of 2860802
# Loaded 2230501 embs of 2860802
# Loaded 2231001 embs of 2860802
# Loaded 2231501 embs of 2860802
# Loaded 2232001 embs of 2860802
# Loaded 2232501 embs of 2860802
# Loaded 2233001 embs of 2860802
# Loaded 2233501 embs of 2860802
# Loaded 2234001 embs of 2860802
# Loaded 2234501 embs of 2860802
# Loaded 2235001 embs of 2860802
# Loaded 2235501 embs of 2860802
# Loaded 2236001 embs of 2860802
# Loaded 2236501 embs of 2860802
# Loaded 2237001 embs of 2860802
# Loaded 2237501 embs of 2860802
# Loaded 2238001 embs of 2860802
# Loaded 2238501 embs of 2860802
# Loaded 2239001 embs of 2860802
# Loaded 2239501 embs of 2860802
# Loaded 2240001 embs of 2860802
# Loaded 2240501 embs of 2860802
# Loaded 2241001 embs of 2860802
# Loaded 2241501 embs of 2860802
# Loaded 2242001 embs of 2860802
# Loaded 2242501 embs of 2860802
# Loaded 2243001 embs of 2860802
# Loaded 2243501 embs of 2860802
# Loaded 2244001 embs of 2860802
# Loaded 2244501 embs of 2860802
#   Loading chunk: 12
# Loaded 2245001 embs of 2860802
# Loaded 2245501 embs of 2860802
# Loaded 2246001 embs of 2860802
# Loaded 2246501 embs of 2860802
# Loaded 2247001 embs of 2860802
# Loaded 2247501 embs of 2860802
# Loaded 2248001 embs of 2860802
# Loaded 2248501 embs of 2860802
# Loaded 2249001 embs of 2860802
# Loaded 2249501 embs of 2860802
# Loaded 2250001 embs of 2860802
# Loaded 2250501 embs of 2860802
# Loaded 2251001 embs of 2860802
# Loaded 2251501 embs of 2860802
# Loaded 2252001 embs of 2860802
# Loaded 2252501 embs of 2860802
# Loaded 2253001 embs of 2860802
# Loaded 2253501 embs of 2860802
# Loaded 2254001 embs of 2860802
# Loaded 2254501 embs of 2860802
# Loaded 2255001 embs of 2860802
# Loaded 2255501 embs of 2860802
# Loaded 2256001 embs of 2860802
# Loaded 2256501 embs of 2860802
# Loaded 2257001 embs of 2860802
# Loaded 2257501 embs of 2860802
# Loaded 2258001 embs of 2860802
# Loaded 2258501 embs of 2860802
# Loaded 2259001 embs of 2860802
# Loaded 2259501 embs of 2860802
# Loaded 2260001 embs of 2860802
# Loaded 2260501 embs of 2860802
# Loaded 2261001 embs of 2860802
# Loaded 2261501 embs of 2860802
# Loaded 2262001 embs of 2860802
# Loaded 2262501 embs of 2860802
# Loaded 2263001 embs of 2860802
# Loaded 2263501 embs of 2860802
# Loaded 2264001 embs of 2860802
# Loaded 2264501 embs of 2860802
# Loaded 2265001 embs of 2860802
# Loaded 2265501 embs of 2860802
# Loaded 2266001 embs of 2860802
# Loaded 2266501 embs of 2860802
# Loaded 2267001 embs of 2860802
# Loaded 2267501 embs of 2860802
# Loaded 2268001 embs of 2860802
# Loaded 2268501 embs of 2860802
# Loaded 2269001 embs of 2860802
# Loaded 2269501 embs of 2860802
# Loaded 2270001 embs of 2860802
# Loaded 2270501 embs of 2860802
# Loaded 2271001 embs of 2860802
# Loaded 2271501 embs of 2860802
# Loaded 2272001 embs of 2860802
# Loaded 2272501 embs of 2860802
# Loaded 2273001 embs of 2860802
# Loaded 2273501 embs of 2860802
# Loaded 2274001 embs of 2860802
# Loaded 2274501 embs of 2860802
# Loaded 2275001 embs of 2860802
# Loaded 2275501 embs of 2860802
# Loaded 2276001 embs of 2860802
# Loaded 2276501 embs of 2860802
# Loaded 2277001 embs of 2860802
# Loaded 2277501 embs of 2860802
# Loaded 2278001 embs of 2860802
# Loaded 2278501 embs of 2860802
# Loaded 2279001 embs of 2860802
# Loaded 2279501 embs of 2860802
# Loaded 2280001 embs of 2860802
# Loaded 2280501 embs of 2860802
# Loaded 2281001 embs of 2860802
# Loaded 2281501 embs of 2860802
# Loaded 2282001 embs of 2860802
# Loaded 2282501 embs of 2860802
# Loaded 2283001 embs of 2860802
# Loaded 2283501 embs of 2860802
# Loaded 2284001 embs of 2860802
# Loaded 2284501 embs of 2860802
# Loaded 2285001 embs of 2860802
# Loaded 2285501 embs of 2860802
# Loaded 2286001 embs of 2860802
# Loaded 2286501 embs of 2860802
# Loaded 2287001 embs of 2860802
# Loaded 2287501 embs of 2860802
# Loaded 2288001 embs of 2860802
# Loaded 2288501 embs of 2860802
# Loaded 2289001 embs of 2860802
# Loaded 2289501 embs of 2860802
# Loaded 2290001 embs of 2860802
# Loaded 2290501 embs of 2860802
# Loaded 2291001 embs of 2860802
# Loaded 2291501 embs of 2860802
# Loaded 2292001 embs of 2860802
# Loaded 2292501 embs of 2860802
# Loaded 2293001 embs of 2860802
# Loaded 2293501 embs of 2860802
# Loaded 2294001 embs of 2860802
# Loaded 2294501 embs of 2860802
# Loaded 2295001 embs of 2860802
# Loaded 2295501 embs of 2860802
# Loaded 2296001 embs of 2860802
# Loaded 2296501 embs of 2860802
# Loaded 2297001 embs of 2860802
# Loaded 2297501 embs of 2860802
# Loaded 2298001 embs of 2860802
# Loaded 2298501 embs of 2860802
# Loaded 2299001 embs of 2860802
# Loaded 2299501 embs of 2860802
# Loaded 2300001 embs of 2860802
# Loaded 2300501 embs of 2860802
# Loaded 2301001 embs of 2860802
# Loaded 2301501 embs of 2860802
# Loaded 2302001 embs of 2860802
# Loaded 2302501 embs of 2860802
# Loaded 2303001 embs of 2860802
# Loaded 2303501 embs of 2860802
# Loaded 2304001 embs of 2860802
# Loaded 2304501 embs of 2860802
# Loaded 2305001 embs of 2860802
# Loaded 2305501 embs of 2860802
# Loaded 2306001 embs of 2860802
# Loaded 2306501 embs of 2860802
# Loaded 2307001 embs of 2860802
# Loaded 2307501 embs of 2860802
# Loaded 2308001 embs of 2860802
# Loaded 2308501 embs of 2860802
# Loaded 2309001 embs of 2860802
# Loaded 2309501 embs of 2860802
# Loaded 2310001 embs of 2860802
# Loaded 2310501 embs of 2860802
# Loaded 2311001 embs of 2860802
# Loaded 2311501 embs of 2860802
# Loaded 2312001 embs of 2860802
# Loaded 2312501 embs of 2860802
# Loaded 2313001 embs of 2860802
# Loaded 2313501 embs of 2860802
# Loaded 2314001 embs of 2860802
# Loaded 2314501 embs of 2860802
# Loaded 2315001 embs of 2860802
# Loaded 2315501 embs of 2860802
# Loaded 2316001 embs of 2860802
# Loaded 2316501 embs of 2860802
# Loaded 2317001 embs of 2860802
# Loaded 2317501 embs of 2860802
# Loaded 2318001 embs of 2860802
# Loaded 2318501 embs of 2860802
# Loaded 2319001 embs of 2860802
# Loaded 2319501 embs of 2860802
# Loaded 2320001 embs of 2860802
# Loaded 2320501 embs of 2860802
# Loaded 2321001 embs of 2860802
# Loaded 2321501 embs of 2860802
# Loaded 2322001 embs of 2860802
# Loaded 2322501 embs of 2860802
# Loaded 2323001 embs of 2860802
# Loaded 2323501 embs of 2860802
# Loaded 2324001 embs of 2860802
# Loaded 2324501 embs of 2860802
# Loaded 2325001 embs of 2860802
# Loaded 2325501 embs of 2860802
# Loaded 2326001 embs of 2860802
# Loaded 2326501 embs of 2860802
# Loaded 2327001 embs of 2860802
# Loaded 2327501 embs of 2860802
# Loaded 2328001 embs of 2860802
# Loaded 2328501 embs of 2860802
# Loaded 2329001 embs of 2860802
# Loaded 2329501 embs of 2860802
# Loaded 2330001 embs of 2860802
# Loaded 2330501 embs of 2860802
# Loaded 2331001 embs of 2860802
# Loaded 2331501 embs of 2860802
# Loaded 2332001 embs of 2860802
# Loaded 2332501 embs of 2860802
# Loaded 2333001 embs of 2860802
# Loaded 2333501 embs of 2860802
# Loaded 2334001 embs of 2860802
# Loaded 2334501 embs of 2860802
# Loaded 2335001 embs of 2860802
# Loaded 2335501 embs of 2860802
# Loaded 2336001 embs of 2860802
# Loaded 2336501 embs of 2860802
# Loaded 2337001 embs of 2860802
# Loaded 2337501 embs of 2860802
# Loaded 2338001 embs of 2860802
# Loaded 2338501 embs of 2860802
# Loaded 2339001 embs of 2860802
# Loaded 2339501 embs of 2860802
# Loaded 2340001 embs of 2860802
# Loaded 2340501 embs of 2860802
# Loaded 2341001 embs of 2860802
# Loaded 2341501 embs of 2860802
# Loaded 2342001 embs of 2860802
# Loaded 2342501 embs of 2860802
# Loaded 2343001 embs of 2860802
# Loaded 2343501 embs of 2860802
# Loaded 2344001 embs of 2860802
# Loaded 2344501 embs of 2860802
# Loaded 2345001 embs of 2860802
# Loaded 2345501 embs of 2860802
# Loaded 2346001 embs of 2860802
# Loaded 2346501 embs of 2860802
# Loaded 2347001 embs of 2860802
# Loaded 2347501 embs of 2860802
# Loaded 2348001 embs of 2860802
# Loaded 2348501 embs of 2860802
# Loaded 2349001 embs of 2860802
# Loaded 2349501 embs of 2860802
# Loaded 2350001 embs of 2860802
# Loaded 2350501 embs of 2860802
# Loaded 2351001 embs of 2860802
# Loaded 2351501 embs of 2860802
# Loaded 2352001 embs of 2860802
# Loaded 2352501 embs of 2860802
# Loaded 2353001 embs of 2860802
# Loaded 2353501 embs of 2860802
# Loaded 2354001 embs of 2860802
# Loaded 2354501 embs of 2860802
# Loaded 2355001 embs of 2860802
# Loaded 2355501 embs of 2860802
# Loaded 2356001 embs of 2860802
# Loaded 2356501 embs of 2860802
# Loaded 2357001 embs of 2860802
# Loaded 2357501 embs of 2860802
# Loaded 2358001 embs of 2860802
# Loaded 2358501 embs of 2860802
# Loaded 2359001 embs of 2860802
# Loaded 2359501 embs of 2860802
# Loaded 2360001 embs of 2860802
# Loaded 2360501 embs of 2860802
# Loaded 2361001 embs of 2860802
# Loaded 2361501 embs of 2860802
# Loaded 2362001 embs of 2860802
# Loaded 2362501 embs of 2860802
# Loaded 2363001 embs of 2860802
# Loaded 2363501 embs of 2860802
# Loaded 2364001 embs of 2860802
# Loaded 2364501 embs of 2860802
# Loaded 2365001 embs of 2860802
# Loaded 2365501 embs of 2860802
# Loaded 2366001 embs of 2860802
# Loaded 2366501 embs of 2860802
# Loaded 2367001 embs of 2860802
# Loaded 2367501 embs of 2860802
# Loaded 2368001 embs of 2860802
# Loaded 2368501 embs of 2860802
# Loaded 2369001 embs of 2860802
# Loaded 2369501 embs of 2860802
# Loaded 2370001 embs of 2860802
# Loaded 2370501 embs of 2860802
# Loaded 2371001 embs of 2860802
# Loaded 2371501 embs of 2860802
# Loaded 2372001 embs of 2860802
# Loaded 2372501 embs of 2860802
# Loaded 2373001 embs of 2860802
# Loaded 2373501 embs of 2860802
# Loaded 2374001 embs of 2860802
# Loaded 2374501 embs of 2860802
# Loaded 2375001 embs of 2860802
# Loaded 2375501 embs of 2860802
# Loaded 2376001 embs of 2860802
# Loaded 2376501 embs of 2860802
# Loaded 2377001 embs of 2860802
# Loaded 2377501 embs of 2860802
# Loaded 2378001 embs of 2860802
# Loaded 2378501 embs of 2860802
# Loaded 2379001 embs of 2860802
# Loaded 2379501 embs of 2860802
# Loaded 2380001 embs of 2860802
# Loaded 2380501 embs of 2860802
# Loaded 2381001 embs of 2860802
# Loaded 2381501 embs of 2860802
# Loaded 2382001 embs of 2860802
# Loaded 2382501 embs of 2860802
# Loaded 2383001 embs of 2860802
# Loaded 2383501 embs of 2860802
# Loaded 2384001 embs of 2860802
# Loaded 2384501 embs of 2860802
# Loaded 2385001 embs of 2860802
# Loaded 2385501 embs of 2860802
# Loaded 2386001 embs of 2860802
# Loaded 2386501 embs of 2860802
# Loaded 2387001 embs of 2860802
# Loaded 2387501 embs of 2860802
# Loaded 2388001 embs of 2860802
# Loaded 2388501 embs of 2860802
# Loaded 2389001 embs of 2860802
# Loaded 2389501 embs of 2860802
# Loaded 2390001 embs of 2860802
# Loaded 2390501 embs of 2860802
# Loaded 2391001 embs of 2860802
# Loaded 2391501 embs of 2860802
# Loaded 2392001 embs of 2860802
# Loaded 2392501 embs of 2860802
# Loaded 2393001 embs of 2860802
# Loaded 2393501 embs of 2860802
# Loaded 2394001 embs of 2860802
# Loaded 2394501 embs of 2860802
# Loaded 2395001 embs of 2860802
# Loaded 2395501 embs of 2860802
# Loaded 2396001 embs of 2860802
# Loaded 2396501 embs of 2860802
# Loaded 2397001 embs of 2860802
# Loaded 2397501 embs of 2860802
# Loaded 2398001 embs of 2860802
# Loaded 2398501 embs of 2860802
# Loaded 2399001 embs of 2860802
# Loaded 2399501 embs of 2860802
# Loaded 2400001 embs of 2860802
# Loaded 2400501 embs of 2860802
# Loaded 2401001 embs of 2860802
# Loaded 2401501 embs of 2860802
# Loaded 2402001 embs of 2860802
# Loaded 2402501 embs of 2860802
# Loaded 2403001 embs of 2860802
# Loaded 2403501 embs of 2860802
# Loaded 2404001 embs of 2860802
# Loaded 2404501 embs of 2860802
# Loaded 2405001 embs of 2860802
# Loaded 2405501 embs of 2860802
# Loaded 2406001 embs of 2860802
# Loaded 2406501 embs of 2860802
# Loaded 2407001 embs of 2860802
# Loaded 2407501 embs of 2860802
# Loaded 2408001 embs of 2860802
# Loaded 2408501 embs of 2860802
# Loaded 2409001 embs of 2860802
# Loaded 2409501 embs of 2860802
# Loaded 2410001 embs of 2860802
# Loaded 2410501 embs of 2860802
# Loaded 2411001 embs of 2860802
# Loaded 2411501 embs of 2860802
# Loaded 2412001 embs of 2860802
# Loaded 2412501 embs of 2860802
# Loaded 2413001 embs of 2860802
# Loaded 2413501 embs of 2860802
# Loaded 2414001 embs of 2860802
# Loaded 2414501 embs of 2860802
# Loaded 2415001 embs of 2860802
# Loaded 2415501 embs of 2860802
# Loaded 2416001 embs of 2860802
# Loaded 2416501 embs of 2860802
# Loaded 2417001 embs of 2860802
# Loaded 2417501 embs of 2860802
# Loaded 2418001 embs of 2860802
# Loaded 2418501 embs of 2860802
# Loaded 2419001 embs of 2860802
# Loaded 2419501 embs of 2860802
# Loaded 2420001 embs of 2860802
# Loaded 2420501 embs of 2860802
# Loaded 2421001 embs of 2860802
# Loaded 2421501 embs of 2860802
# Loaded 2422001 embs of 2860802
# Loaded 2422501 embs of 2860802
# Loaded 2423001 embs of 2860802
# Loaded 2423501 embs of 2860802
# Loaded 2424001 embs of 2860802
# Loaded 2424501 embs of 2860802
# Loaded 2425001 embs of 2860802
# Loaded 2425501 embs of 2860802
# Loaded 2426001 embs of 2860802
# Loaded 2426501 embs of 2860802
# Loaded 2427001 embs of 2860802
# Loaded 2427501 embs of 2860802
# Loaded 2428001 embs of 2860802
# Loaded 2428501 embs of 2860802
# Loaded 2429001 embs of 2860802
# Loaded 2429501 embs of 2860802
# Loaded 2430001 embs of 2860802
# Loaded 2430501 embs of 2860802
# Loaded 2431001 embs of 2860802
# Loaded 2431501 embs of 2860802
# Loaded 2432001 embs of 2860802
# Loaded 2432501 embs of 2860802
# Loaded 2433001 embs of 2860802
# Loaded 2433501 embs of 2860802
# Loaded 2434001 embs of 2860802
# Loaded 2434501 embs of 2860802
# Loaded 2435001 embs of 2860802
# Loaded 2435501 embs of 2860802
# Loaded 2436001 embs of 2860802
# Loaded 2436501 embs of 2860802
# Loaded 2437001 embs of 2860802
# Loaded 2437501 embs of 2860802
#   Loading chunk: 13
# Loaded 2438001 embs of 2860802
# Loaded 2438501 embs of 2860802
# Loaded 2439001 embs of 2860802
# Loaded 2439501 embs of 2860802
# Loaded 2440001 embs of 2860802
# Loaded 2440501 embs of 2860802
# Loaded 2441001 embs of 2860802
# Loaded 2441501 embs of 2860802
# Loaded 2442001 embs of 2860802
# Loaded 2442501 embs of 2860802
# Loaded 2443001 embs of 2860802
# Loaded 2443501 embs of 2860802
# Loaded 2444001 embs of 2860802
# Loaded 2444501 embs of 2860802
# Loaded 2445001 embs of 2860802
# Loaded 2445501 embs of 2860802
# Loaded 2446001 embs of 2860802
# Loaded 2446501 embs of 2860802
# Loaded 2447001 embs of 2860802
# Loaded 2447501 embs of 2860802
# Loaded 2448001 embs of 2860802
# Loaded 2448501 embs of 2860802
# Loaded 2449001 embs of 2860802
# Loaded 2449501 embs of 2860802
# Loaded 2450001 embs of 2860802
# Loaded 2450501 embs of 2860802
# Loaded 2451001 embs of 2860802
# Loaded 2451501 embs of 2860802
# Loaded 2452001 embs of 2860802
# Loaded 2452501 embs of 2860802
# Loaded 2453001 embs of 2860802
# Loaded 2453501 embs of 2860802
# Loaded 2454001 embs of 2860802
# Loaded 2454501 embs of 2860802
# Loaded 2455001 embs of 2860802
# Loaded 2455501 embs of 2860802
# Loaded 2456001 embs of 2860802
# Loaded 2456501 embs of 2860802
# Loaded 2457001 embs of 2860802
# Loaded 2457501 embs of 2860802
# Loaded 2458001 embs of 2860802
# Loaded 2458501 embs of 2860802
# Loaded 2459001 embs of 2860802
# Loaded 2459501 embs of 2860802
# Loaded 2460001 embs of 2860802
# Loaded 2460501 embs of 2860802
# Loaded 2461001 embs of 2860802
# Loaded 2461501 embs of 2860802
# Loaded 2462001 embs of 2860802
# Loaded 2462501 embs of 2860802
# Loaded 2463001 embs of 2860802
# Loaded 2463501 embs of 2860802
# Loaded 2464001 embs of 2860802
# Loaded 2464501 embs of 2860802
# Loaded 2465001 embs of 2860802
# Loaded 2465501 embs of 2860802
# Loaded 2466001 embs of 2860802
# Loaded 2466501 embs of 2860802
# Loaded 2467001 embs of 2860802
# Loaded 2467501 embs of 2860802
# Loaded 2468001 embs of 2860802
# Loaded 2468501 embs of 2860802
# Loaded 2469001 embs of 2860802
# Loaded 2469501 embs of 2860802
# Loaded 2470001 embs of 2860802
# Loaded 2470501 embs of 2860802
# Loaded 2471001 embs of 2860802
# Loaded 2471501 embs of 2860802
# Loaded 2472001 embs of 2860802
# Loaded 2472501 embs of 2860802
# Loaded 2473001 embs of 2860802
# Loaded 2473501 embs of 2860802
# Loaded 2474001 embs of 2860802
# Loaded 2474501 embs of 2860802
# Loaded 2475001 embs of 2860802
# Loaded 2475501 embs of 2860802
# Loaded 2476001 embs of 2860802
# Loaded 2476501 embs of 2860802
# Loaded 2477001 embs of 2860802
# Loaded 2477501 embs of 2860802
# Loaded 2478001 embs of 2860802
# Loaded 2478501 embs of 2860802
# Loaded 2479001 embs of 2860802
# Loaded 2479501 embs of 2860802
# Loaded 2480001 embs of 2860802
# Loaded 2480501 embs of 2860802
# Loaded 2481001 embs of 2860802
# Loaded 2481501 embs of 2860802
# Loaded 2482001 embs of 2860802
# Loaded 2482501 embs of 2860802
# Loaded 2483001 embs of 2860802
# Loaded 2483501 embs of 2860802
# Loaded 2484001 embs of 2860802
# Loaded 2484501 embs of 2860802
# Loaded 2485001 embs of 2860802
# Loaded 2485501 embs of 2860802
# Loaded 2486001 embs of 2860802
# Loaded 2486501 embs of 2860802
# Loaded 2487001 embs of 2860802
# Loaded 2487501 embs of 2860802
# Loaded 2488001 embs of 2860802
# Loaded 2488501 embs of 2860802
# Loaded 2489001 embs of 2860802
# Loaded 2489501 embs of 2860802
# Loaded 2490001 embs of 2860802
# Loaded 2490501 embs of 2860802
# Loaded 2491001 embs of 2860802
# Loaded 2491501 embs of 2860802
# Loaded 2492001 embs of 2860802
# Loaded 2492501 embs of 2860802
# Loaded 2493001 embs of 2860802
# Loaded 2493501 embs of 2860802
# Loaded 2494001 embs of 2860802
# Loaded 2494501 embs of 2860802
# Loaded 2495001 embs of 2860802
# Loaded 2495501 embs of 2860802
# Loaded 2496001 embs of 2860802
# Loaded 2496501 embs of 2860802
# Loaded 2497001 embs of 2860802
# Loaded 2497501 embs of 2860802
# Loaded 2498001 embs of 2860802
# Loaded 2498501 embs of 2860802
# Loaded 2499001 embs of 2860802
# Loaded 2499501 embs of 2860802
# Loaded 2500001 embs of 2860802
# Loaded 2500501 embs of 2860802
# Loaded 2501001 embs of 2860802
# Loaded 2501501 embs of 2860802
# Loaded 2502001 embs of 2860802
# Loaded 2502501 embs of 2860802
# Loaded 2503001 embs of 2860802
# Loaded 2503501 embs of 2860802
# Loaded 2504001 embs of 2860802
# Loaded 2504501 embs of 2860802
# Loaded 2505001 embs of 2860802
# Loaded 2505501 embs of 2860802
# Loaded 2506001 embs of 2860802
# Loaded 2506501 embs of 2860802
# Loaded 2507001 embs of 2860802
# Loaded 2507501 embs of 2860802
# Loaded 2508001 embs of 2860802
# Loaded 2508501 embs of 2860802
# Loaded 2509001 embs of 2860802
# Loaded 2509501 embs of 2860802
# Loaded 2510001 embs of 2860802
# Loaded 2510501 embs of 2860802
# Loaded 2511001 embs of 2860802
# Loaded 2511501 embs of 2860802
# Loaded 2512001 embs of 2860802
# Loaded 2512501 embs of 2860802
# Loaded 2513001 embs of 2860802
# Loaded 2513501 embs of 2860802
# Loaded 2514001 embs of 2860802
# Loaded 2514501 embs of 2860802
# Loaded 2515001 embs of 2860802
# Loaded 2515501 embs of 2860802
# Loaded 2516001 embs of 2860802
# Loaded 2516501 embs of 2860802
# Loaded 2517001 embs of 2860802
# Loaded 2517501 embs of 2860802
# Loaded 2518001 embs of 2860802
# Loaded 2518501 embs of 2860802
# Loaded 2519001 embs of 2860802
# Loaded 2519501 embs of 2860802
# Loaded 2520001 embs of 2860802
# Loaded 2520501 embs of 2860802
# Loaded 2521001 embs of 2860802
# Loaded 2521501 embs of 2860802
# Loaded 2522001 embs of 2860802
# Loaded 2522501 embs of 2860802
# Loaded 2523001 embs of 2860802
# Loaded 2523501 embs of 2860802
# Loaded 2524001 embs of 2860802
# Loaded 2524501 embs of 2860802
# Loaded 2525001 embs of 2860802
# Loaded 2525501 embs of 2860802
# Loaded 2526001 embs of 2860802
# Loaded 2526501 embs of 2860802
# Loaded 2527001 embs of 2860802
# Loaded 2527501 embs of 2860802
# Loaded 2528001 embs of 2860802
# Loaded 2528501 embs of 2860802
# Loaded 2529001 embs of 2860802
# Loaded 2529501 embs of 2860802
# Loaded 2530001 embs of 2860802
# Loaded 2530501 embs of 2860802
# Loaded 2531001 embs of 2860802
# Loaded 2531501 embs of 2860802
# Loaded 2532001 embs of 2860802
# Loaded 2532501 embs of 2860802
# Loaded 2533001 embs of 2860802
# Loaded 2533501 embs of 2860802
# Loaded 2534001 embs of 2860802
# Loaded 2534501 embs of 2860802
# Loaded 2535001 embs of 2860802
# Loaded 2535501 embs of 2860802
# Loaded 2536001 embs of 2860802
# Loaded 2536501 embs of 2860802
# Loaded 2537001 embs of 2860802
# Loaded 2537501 embs of 2860802
# Loaded 2538001 embs of 2860802
# Loaded 2538501 embs of 2860802
# Loaded 2539001 embs of 2860802
# Loaded 2539501 embs of 2860802
# Loaded 2540001 embs of 2860802
# Loaded 2540501 embs of 2860802
# Loaded 2541001 embs of 2860802
# Loaded 2541501 embs of 2860802
# Loaded 2542001 embs of 2860802
# Loaded 2542501 embs of 2860802
# Loaded 2543001 embs of 2860802
# Loaded 2543501 embs of 2860802
# Loaded 2544001 embs of 2860802
# Loaded 2544501 embs of 2860802
# Loaded 2545001 embs of 2860802
# Loaded 2545501 embs of 2860802
# Loaded 2546001 embs of 2860802
# Loaded 2546501 embs of 2860802
# Loaded 2547001 embs of 2860802
# Loaded 2547501 embs of 2860802
# Loaded 2548001 embs of 2860802
# Loaded 2548501 embs of 2860802
# Loaded 2549001 embs of 2860802
# Loaded 2549501 embs of 2860802
# Loaded 2550001 embs of 2860802
# Loaded 2550501 embs of 2860802
# Loaded 2551001 embs of 2860802
# Loaded 2551501 embs of 2860802
# Loaded 2552001 embs of 2860802
# Loaded 2552501 embs of 2860802
# Loaded 2553001 embs of 2860802
# Loaded 2553501 embs of 2860802
# Loaded 2554001 embs of 2860802
# Loaded 2554501 embs of 2860802
# Loaded 2555001 embs of 2860802
# Loaded 2555501 embs of 2860802
# Loaded 2556001 embs of 2860802
# Loaded 2556501 embs of 2860802
# Loaded 2557001 embs of 2860802
# Loaded 2557501 embs of 2860802
# Loaded 2558001 embs of 2860802
# Loaded 2558501 embs of 2860802
# Loaded 2559001 embs of 2860802
# Loaded 2559501 embs of 2860802
# Loaded 2560001 embs of 2860802
# Loaded 2560501 embs of 2860802
# Loaded 2561001 embs of 2860802
# Loaded 2561501 embs of 2860802
# Loaded 2562001 embs of 2860802
# Loaded 2562501 embs of 2860802
# Loaded 2563001 embs of 2860802
# Loaded 2563501 embs of 2860802
# Loaded 2564001 embs of 2860802
# Loaded 2564501 embs of 2860802
# Loaded 2565001 embs of 2860802
# Loaded 2565501 embs of 2860802
# Loaded 2566001 embs of 2860802
# Loaded 2566501 embs of 2860802
# Loaded 2567001 embs of 2860802
# Loaded 2567501 embs of 2860802
# Loaded 2568001 embs of 2860802
# Loaded 2568501 embs of 2860802
# Loaded 2569001 embs of 2860802
# Loaded 2569501 embs of 2860802
# Loaded 2570001 embs of 2860802
# Loaded 2570501 embs of 2860802
# Loaded 2571001 embs of 2860802
# Loaded 2571501 embs of 2860802
# Loaded 2572001 embs of 2860802
# Loaded 2572501 embs of 2860802
# Loaded 2573001 embs of 2860802
# Loaded 2573501 embs of 2860802
# Loaded 2574001 embs of 2860802
# Loaded 2574501 embs of 2860802
# Loaded 2575001 embs of 2860802
# Loaded 2575501 embs of 2860802
# Loaded 2576001 embs of 2860802
# Loaded 2576501 embs of 2860802
# Loaded 2577001 embs of 2860802
# Loaded 2577501 embs of 2860802
# Loaded 2578001 embs of 2860802
# Loaded 2578501 embs of 2860802
# Loaded 2579001 embs of 2860802
# Loaded 2579501 embs of 2860802
# Loaded 2580001 embs of 2860802
# Loaded 2580501 embs of 2860802
# Loaded 2581001 embs of 2860802
# Loaded 2581501 embs of 2860802
# Loaded 2582001 embs of 2860802
# Loaded 2582501 embs of 2860802
# Loaded 2583001 embs of 2860802
# Loaded 2583501 embs of 2860802
# Loaded 2584001 embs of 2860802
# Loaded 2584501 embs of 2860802
# Loaded 2585001 embs of 2860802
# Loaded 2585501 embs of 2860802
# Loaded 2586001 embs of 2860802
# Loaded 2586501 embs of 2860802
# Loaded 2587001 embs of 2860802
# Loaded 2587501 embs of 2860802
# Loaded 2588001 embs of 2860802
# Loaded 2588501 embs of 2860802
# Loaded 2589001 embs of 2860802
# Loaded 2589501 embs of 2860802
# Loaded 2590001 embs of 2860802
# Loaded 2590501 embs of 2860802
# Loaded 2591001 embs of 2860802
# Loaded 2591501 embs of 2860802
# Loaded 2592001 embs of 2860802
# Loaded 2592501 embs of 2860802
# Loaded 2593001 embs of 2860802
# Loaded 2593501 embs of 2860802
# Loaded 2594001 embs of 2860802
# Loaded 2594501 embs of 2860802
# Loaded 2595001 embs of 2860802
# Loaded 2595501 embs of 2860802
# Loaded 2596001 embs of 2860802
# Loaded 2596501 embs of 2860802
# Loaded 2597001 embs of 2860802
# Loaded 2597501 embs of 2860802
# Loaded 2598001 embs of 2860802
# Loaded 2598501 embs of 2860802
# Loaded 2599001 embs of 2860802
# Loaded 2599501 embs of 2860802
# Loaded 2600001 embs of 2860802
# Loaded 2600501 embs of 2860802
# Loaded 2601001 embs of 2860802
# Loaded 2601501 embs of 2860802
# Loaded 2602001 embs of 2860802
# Loaded 2602501 embs of 2860802
# Loaded 2603001 embs of 2860802
# Loaded 2603501 embs of 2860802
# Loaded 2604001 embs of 2860802
# Loaded 2604501 embs of 2860802
# Loaded 2605001 embs of 2860802
# Loaded 2605501 embs of 2860802
# Loaded 2606001 embs of 2860802
# Loaded 2606501 embs of 2860802
# Loaded 2607001 embs of 2860802
# Loaded 2607501 embs of 2860802
# Loaded 2608001 embs of 2860802
# Loaded 2608501 embs of 2860802
# Loaded 2609001 embs of 2860802
# Loaded 2609501 embs of 2860802
# Loaded 2610001 embs of 2860802
# Loaded 2610501 embs of 2860802
# Loaded 2611001 embs of 2860802
# Loaded 2611501 embs of 2860802
# Loaded 2612001 embs of 2860802
# Loaded 2612501 embs of 2860802
# Loaded 2613001 embs of 2860802
# Loaded 2613501 embs of 2860802
# Loaded 2614001 embs of 2860802
# Loaded 2614501 embs of 2860802
# Loaded 2615001 embs of 2860802
# Loaded 2615501 embs of 2860802
# Loaded 2616001 embs of 2860802
# Loaded 2616501 embs of 2860802
# Loaded 2617001 embs of 2860802
# Loaded 2617501 embs of 2860802
# Loaded 2618001 embs of 2860802
# Loaded 2618501 embs of 2860802
# Loaded 2619001 embs of 2860802
# Loaded 2619501 embs of 2860802
# Loaded 2620001 embs of 2860802
# Loaded 2620501 embs of 2860802
# Loaded 2621001 embs of 2860802
# Loaded 2621501 embs of 2860802
# Loaded 2622001 embs of 2860802
# Loaded 2622501 embs of 2860802
# Loaded 2623001 embs of 2860802
# Loaded 2623501 embs of 2860802
# Loaded 2624001 embs of 2860802
# Loaded 2624501 embs of 2860802
# Loaded 2625001 embs of 2860802
# Loaded 2625501 embs of 2860802
# Loaded 2626001 embs of 2860802
# Loaded 2626501 embs of 2860802
# Loaded 2627001 embs of 2860802
# Loaded 2627501 embs of 2860802
# Loaded 2628001 embs of 2860802
# Loaded 2628501 embs of 2860802
# Loaded 2629001 embs of 2860802
# Loaded 2629501 embs of 2860802
#   Loading chunk: 14
# Loaded 2630001 embs of 2860802
# Loaded 2630501 embs of 2860802
# Loaded 2631001 embs of 2860802
# Loaded 2631501 embs of 2860802
# Loaded 2632001 embs of 2860802
# Loaded 2632501 embs of 2860802
# Loaded 2633001 embs of 2860802
# Loaded 2633501 embs of 2860802
# Loaded 2634001 embs of 2860802
# Loaded 2634501 embs of 2860802
# Loaded 2635001 embs of 2860802
# Loaded 2635501 embs of 2860802
# Loaded 2636001 embs of 2860802
# Loaded 2636501 embs of 2860802
# Loaded 2637001 embs of 2860802
# Loaded 2637501 embs of 2860802
# Loaded 2638001 embs of 2860802
# Loaded 2638501 embs of 2860802
# Loaded 2639001 embs of 2860802
# Loaded 2639501 embs of 2860802
# Loaded 2640001 embs of 2860802
# Loaded 2640501 embs of 2860802
# Loaded 2641001 embs of 2860802
# Loaded 2641501 embs of 2860802
# Loaded 2642001 embs of 2860802
# Loaded 2642501 embs of 2860802
# Loaded 2643001 embs of 2860802
# Loaded 2643501 embs of 2860802
# Loaded 2644001 embs of 2860802
# Loaded 2644501 embs of 2860802
# Loaded 2645001 embs of 2860802
# Loaded 2645501 embs of 2860802
# Loaded 2646001 embs of 2860802
# Loaded 2646501 embs of 2860802
# Loaded 2647001 embs of 2860802
# Loaded 2647501 embs of 2860802
# Loaded 2648001 embs of 2860802
# Loaded 2648501 embs of 2860802
# Loaded 2649001 embs of 2860802
# Loaded 2649501 embs of 2860802
# Loaded 2650001 embs of 2860802
# Loaded 2650501 embs of 2860802
# Loaded 2651001 embs of 2860802
# Loaded 2651501 embs of 2860802
# Loaded 2652001 embs of 2860802
# Loaded 2652501 embs of 2860802
# Loaded 2653001 embs of 2860802
# Loaded 2653501 embs of 2860802
# Loaded 2654001 embs of 2860802
# Loaded 2654501 embs of 2860802
# Loaded 2655001 embs of 2860802
# Loaded 2655501 embs of 2860802
# Loaded 2656001 embs of 2860802
# Loaded 2656501 embs of 2860802
# Loaded 2657001 embs of 2860802
# Loaded 2657501 embs of 2860802
# Loaded 2658001 embs of 2860802
# Loaded 2658501 embs of 2860802
# Loaded 2659001 embs of 2860802
# Loaded 2659501 embs of 2860802
# Loaded 2660001 embs of 2860802
# Loaded 2660501 embs of 2860802
# Loaded 2661001 embs of 2860802
# Loaded 2661501 embs of 2860802
# Loaded 2662001 embs of 2860802
# Loaded 2662501 embs of 2860802
# Loaded 2663001 embs of 2860802
# Loaded 2663501 embs of 2860802
# Loaded 2664001 embs of 2860802
# Loaded 2664501 embs of 2860802
# Loaded 2665001 embs of 2860802
# Loaded 2665501 embs of 2860802
# Loaded 2666001 embs of 2860802
# Loaded 2666501 embs of 2860802
# Loaded 2667001 embs of 2860802
# Loaded 2667501 embs of 2860802
# Loaded 2668001 embs of 2860802
# Loaded 2668501 embs of 2860802
# Loaded 2669001 embs of 2860802
# Loaded 2669501 embs of 2860802
# Loaded 2670001 embs of 2860802
# Loaded 2670501 embs of 2860802
# Loaded 2671001 embs of 2860802
# Loaded 2671501 embs of 2860802
# Loaded 2672001 embs of 2860802
# Loaded 2672501 embs of 2860802
# Loaded 2673001 embs of 2860802
# Loaded 2673501 embs of 2860802
# Loaded 2674001 embs of 2860802
# Loaded 2674501 embs of 2860802
# Loaded 2675001 embs of 2860802
# Loaded 2675501 embs of 2860802
# Loaded 2676001 embs of 2860802
# Loaded 2676501 embs of 2860802
# Loaded 2677001 embs of 2860802
# Loaded 2677501 embs of 2860802
# Loaded 2678001 embs of 2860802
# Loaded 2678501 embs of 2860802
# Loaded 2679001 embs of 2860802
# Loaded 2679501 embs of 2860802
# Loaded 2680001 embs of 2860802
# Loaded 2680501 embs of 2860802
# Loaded 2681001 embs of 2860802
# Loaded 2681501 embs of 2860802
# Loaded 2682001 embs of 2860802
# Loaded 2682501 embs of 2860802
# Loaded 2683001 embs of 2860802
# Loaded 2683501 embs of 2860802
# Loaded 2684001 embs of 2860802
# Loaded 2684501 embs of 2860802
# Loaded 2685001 embs of 2860802
# Loaded 2685501 embs of 2860802
# Loaded 2686001 embs of 2860802
# Loaded 2686501 embs of 2860802
# Loaded 2687001 embs of 2860802
# Loaded 2687501 embs of 2860802
# Loaded 2688001 embs of 2860802
# Loaded 2688501 embs of 2860802
# Loaded 2689001 embs of 2860802
# Loaded 2689501 embs of 2860802
# Loaded 2690001 embs of 2860802
# Loaded 2690501 embs of 2860802
# Loaded 2691001 embs of 2860802
# Loaded 2691501 embs of 2860802
# Loaded 2692001 embs of 2860802
# Loaded 2692501 embs of 2860802
# Loaded 2693001 embs of 2860802
# Loaded 2693501 embs of 2860802
# Loaded 2694001 embs of 2860802
# Loaded 2694501 embs of 2860802
# Loaded 2695001 embs of 2860802
# Loaded 2695501 embs of 2860802
# Loaded 2696001 embs of 2860802
# Loaded 2696501 embs of 2860802
# Loaded 2697001 embs of 2860802
# Loaded 2697501 embs of 2860802
# Loaded 2698001 embs of 2860802
# Loaded 2698501 embs of 2860802
# Loaded 2699001 embs of 2860802
# Loaded 2699501 embs of 2860802
# Loaded 2700001 embs of 2860802
# Loaded 2700501 embs of 2860802
# Loaded 2701001 embs of 2860802
# Loaded 2701501 embs of 2860802
# Loaded 2702001 embs of 2860802
# Loaded 2702501 embs of 2860802
# Loaded 2703001 embs of 2860802
# Loaded 2703501 embs of 2860802
# Loaded 2704001 embs of 2860802
# Loaded 2704501 embs of 2860802
# Loaded 2705001 embs of 2860802
# Loaded 2705501 embs of 2860802
# Loaded 2706001 embs of 2860802
# Loaded 2706501 embs of 2860802
# Loaded 2707001 embs of 2860802
# Loaded 2707501 embs of 2860802
# Loaded 2708001 embs of 2860802
# Loaded 2708501 embs of 2860802
# Loaded 2709001 embs of 2860802
# Loaded 2709501 embs of 2860802
# Loaded 2710001 embs of 2860802
# Loaded 2710501 embs of 2860802
# Loaded 2711001 embs of 2860802
# Loaded 2711501 embs of 2860802
# Loaded 2712001 embs of 2860802
# Loaded 2712501 embs of 2860802
# Loaded 2713001 embs of 2860802
# Loaded 2713501 embs of 2860802
# Loaded 2714001 embs of 2860802
# Loaded 2714501 embs of 2860802
# Loaded 2715001 embs of 2860802
# Loaded 2715501 embs of 2860802
# Loaded 2716001 embs of 2860802
# Loaded 2716501 embs of 2860802
# Loaded 2717001 embs of 2860802
# Loaded 2717501 embs of 2860802
# Loaded 2718001 embs of 2860802
# Loaded 2718501 embs of 2860802
# Loaded 2719001 embs of 2860802
# Loaded 2719501 embs of 2860802
# Loaded 2720001 embs of 2860802
# Loaded 2720501 embs of 2860802
# Loaded 2721001 embs of 2860802
# Loaded 2721501 embs of 2860802
# Loaded 2722001 embs of 2860802
# Loaded 2722501 embs of 2860802
# Loaded 2723001 embs of 2860802
# Loaded 2723501 embs of 2860802
# Loaded 2724001 embs of 2860802
# Loaded 2724501 embs of 2860802
# Loaded 2725001 embs of 2860802
# Loaded 2725501 embs of 2860802
# Loaded 2726001 embs of 2860802
# Loaded 2726501 embs of 2860802
# Loaded 2727001 embs of 2860802
# Loaded 2727501 embs of 2860802
# Loaded 2728001 embs of 2860802
# Loaded 2728501 embs of 2860802
# Loaded 2729001 embs of 2860802
# Loaded 2729501 embs of 2860802
# Loaded 2730001 embs of 2860802
# Loaded 2730501 embs of 2860802
# Loaded 2731001 embs of 2860802
# Loaded 2731501 embs of 2860802
# Loaded 2732001 embs of 2860802
# Loaded 2732501 embs of 2860802
# Loaded 2733001 embs of 2860802
# Loaded 2733501 embs of 2860802
# Loaded 2734001 embs of 2860802
# Loaded 2734501 embs of 2860802
# Loaded 2735001 embs of 2860802
# Loaded 2735501 embs of 2860802
# Loaded 2736001 embs of 2860802
# Loaded 2736501 embs of 2860802
# Loaded 2737001 embs of 2860802
# Loaded 2737501 embs of 2860802
# Loaded 2738001 embs of 2860802
# Loaded 2738501 embs of 2860802
# Loaded 2739001 embs of 2860802
# Loaded 2739501 embs of 2860802
# Loaded 2740001 embs of 2860802
# Loaded 2740501 embs of 2860802
# Loaded 2741001 embs of 2860802
# Loaded 2741501 embs of 2860802
# Loaded 2742001 embs of 2860802
# Loaded 2742501 embs of 2860802
# Loaded 2743001 embs of 2860802
# Loaded 2743501 embs of 2860802
# Loaded 2744001 embs of 2860802
# Loaded 2744501 embs of 2860802
# Loaded 2745001 embs of 2860802
# Loaded 2745501 embs of 2860802
# Loaded 2746001 embs of 2860802
# Loaded 2746501 embs of 2860802
# Loaded 2747001 embs of 2860802
# Loaded 2747501 embs of 2860802
# Loaded 2748001 embs of 2860802
# Loaded 2748501 embs of 2860802
# Loaded 2749001 embs of 2860802
# Loaded 2749501 embs of 2860802
# Loaded 2750001 embs of 2860802
# Loaded 2750501 embs of 2860802
# Loaded 2751001 embs of 2860802
# Loaded 2751501 embs of 2860802
# Loaded 2752001 embs of 2860802
# Loaded 2752501 embs of 2860802
# Loaded 2753001 embs of 2860802
# Loaded 2753501 embs of 2860802
# Loaded 2754001 embs of 2860802
# Loaded 2754501 embs of 2860802
# Loaded 2755001 embs of 2860802
# Loaded 2755501 embs of 2860802
# Loaded 2756001 embs of 2860802
# Loaded 2756501 embs of 2860802
# Loaded 2757001 embs of 2860802
# Loaded 2757501 embs of 2860802
# Loaded 2758001 embs of 2860802
# Loaded 2758501 embs of 2860802
# Loaded 2759001 embs of 2860802
# Loaded 2759501 embs of 2860802
# Loaded 2760001 embs of 2860802
# Loaded 2760501 embs of 2860802
# Loaded 2761001 embs of 2860802
# Loaded 2761501 embs of 2860802
# Loaded 2762001 embs of 2860802
# Loaded 2762501 embs of 2860802
# Loaded 2763001 embs of 2860802
# Loaded 2763501 embs of 2860802
# Loaded 2764001 embs of 2860802
# Loaded 2764501 embs of 2860802
# Loaded 2765001 embs of 2860802
# Loaded 2765501 embs of 2860802
# Loaded 2766001 embs of 2860802
# Loaded 2766501 embs of 2860802
# Loaded 2767001 embs of 2860802
# Loaded 2767501 embs of 2860802
# Loaded 2768001 embs of 2860802
# Loaded 2768501 embs of 2860802
# Loaded 2769001 embs of 2860802
# Loaded 2769501 embs of 2860802
# Loaded 2770001 embs of 2860802
# Loaded 2770501 embs of 2860802
# Loaded 2771001 embs of 2860802
# Loaded 2771501 embs of 2860802
# Loaded 2772001 embs of 2860802
# Loaded 2772501 embs of 2860802
# Loaded 2773001 embs of 2860802
# Loaded 2773501 embs of 2860802
# Loaded 2774001 embs of 2860802
# Loaded 2774501 embs of 2860802
# Loaded 2775001 embs of 2860802
# Loaded 2775501 embs of 2860802
# Loaded 2776001 embs of 2860802
# Loaded 2776501 embs of 2860802
# Loaded 2777001 embs of 2860802
# Loaded 2777501 embs of 2860802
# Loaded 2778001 embs of 2860802
# Loaded 2778501 embs of 2860802
# Loaded 2779001 embs of 2860802
# Loaded 2779501 embs of 2860802
# Loaded 2780001 embs of 2860802
# Loaded 2780501 embs of 2860802
# Loaded 2781001 embs of 2860802
# Loaded 2781501 embs of 2860802
# Loaded 2782001 embs of 2860802
# Loaded 2782501 embs of 2860802
# Loaded 2783001 embs of 2860802
# Loaded 2783501 embs of 2860802
# Loaded 2784001 embs of 2860802
# Loaded 2784501 embs of 2860802
# Loaded 2785001 embs of 2860802
# Loaded 2785501 embs of 2860802
# Loaded 2786001 embs of 2860802
# Loaded 2786501 embs of 2860802
# Loaded 2787001 embs of 2860802
# Loaded 2787501 embs of 2860802
# Loaded 2788001 embs of 2860802
# Loaded 2788501 embs of 2860802
# Loaded 2789001 embs of 2860802
# Loaded 2789501 embs of 2860802
# Loaded 2790001 embs of 2860802
# Loaded 2790501 embs of 2860802
# Loaded 2791001 embs of 2860802
# Loaded 2791501 embs of 2860802
# Loaded 2792001 embs of 2860802
# Loaded 2792501 embs of 2860802
# Loaded 2793001 embs of 2860802
# Loaded 2793501 embs of 2860802
# Loaded 2794001 embs of 2860802
# Loaded 2794501 embs of 2860802
# Loaded 2795001 embs of 2860802
# Loaded 2795501 embs of 2860802
# Loaded 2796001 embs of 2860802
# Loaded 2796501 embs of 2860802
# Loaded 2797001 embs of 2860802
# Loaded 2797501 embs of 2860802
# Loaded 2798001 embs of 2860802
# Loaded 2798501 embs of 2860802
# Loaded 2799001 embs of 2860802
# Loaded 2799501 embs of 2860802
# Loaded 2800001 embs of 2860802
# Loaded 2800501 embs of 2860802
# Loaded 2801001 embs of 2860802
# Loaded 2801501 embs of 2860802
# Loaded 2802001 embs of 2860802
# Loaded 2802501 embs of 2860802
# Loaded 2803001 embs of 2860802
# Loaded 2803501 embs of 2860802
# Loaded 2804001 embs of 2860802
# Loaded 2804501 embs of 2860802
# Loaded 2805001 embs of 2860802
# Loaded 2805501 embs of 2860802
# Loaded 2806001 embs of 2860802
# Loaded 2806501 embs of 2860802
# Loaded 2807001 embs of 2860802
# Loaded 2807501 embs of 2860802
# Loaded 2808001 embs of 2860802
# Loaded 2808501 embs of 2860802
# Loaded 2809001 embs of 2860802
# Loaded 2809501 embs of 2860802
# Loaded 2810001 embs of 2860802
# Loaded 2810501 embs of 2860802
# Loaded 2811001 embs of 2860802
# Loaded 2811501 embs of 2860802
# Loaded 2812001 embs of 2860802
# Loaded 2812501 embs of 2860802
# Loaded 2813001 embs of 2860802
# Loaded 2813501 embs of 2860802
# Loaded 2814001 embs of 2860802
# Loaded 2814501 embs of 2860802
# Loaded 2815001 embs of 2860802
# Loaded 2815501 embs of 2860802
# Loaded 2816001 embs of 2860802
# Loaded 2816501 embs of 2860802
# Loaded 2817001 embs of 2860802
# Loaded 2817501 embs of 2860802
# Loaded 2818001 embs of 2860802
# Loaded 2818501 embs of 2860802
# Loaded 2819001 embs of 2860802
# Loaded 2819501 embs of 2860802
# Loaded 2820001 embs of 2860802
# Loaded 2820501 embs of 2860802
# Loaded 2821001 embs of 2860802
# Loaded 2821501 embs of 2860802
# Loaded 2822001 embs of 2860802
#   Loading chunk: 15
# Loaded 2822501 embs of 2860802
# Loaded 2823001 embs of 2860802
# Loaded 2823501 embs of 2860802
# Loaded 2824001 embs of 2860802
# Loaded 2824501 embs of 2860802
# Loaded 2825001 embs of 2860802
# Loaded 2825501 embs of 2860802
# Loaded 2826001 embs of 2860802
# Loaded 2826501 embs of 2860802
# Loaded 2827001 embs of 2860802
# Loaded 2827501 embs of 2860802
# Loaded 2828001 embs of 2860802
# Loaded 2828501 embs of 2860802
# Loaded 2829001 embs of 2860802
# Loaded 2829501 embs of 2860802
# Loaded 2830001 embs of 2860802
# Loaded 2830501 embs of 2860802
# Loaded 2831001 embs of 2860802
# Loaded 2831501 embs of 2860802
# Loaded 2832001 embs of 2860802
# Loaded 2832501 embs of 2860802
# Loaded 2833001 embs of 2860802
# Loaded 2833501 embs of 2860802
# Loaded 2834001 embs of 2860802
# Loaded 2834501 embs of 2860802
# Loaded 2835001 embs of 2860802
# Loaded 2835501 embs of 2860802
# Loaded 2836001 embs of 2860802
# Loaded 2836501 embs of 2860802
# Loaded 2837001 embs of 2860802
# Loaded 2837501 embs of 2860802
# Loaded 2838001 embs of 2860802
# Loaded 2838501 embs of 2860802
# Loaded 2839001 embs of 2860802
# Loaded 2839501 embs of 2860802
# Loaded 2840001 embs of 2860802
# Loaded 2840501 embs of 2860802
# Loaded 2841001 embs of 2860802
# Loaded 2841501 embs of 2860802
# Loaded 2842001 embs of 2860802
# Loaded 2842501 embs of 2860802
# Loaded 2843001 embs of 2860802
# Loaded 2843501 embs of 2860802
# Loaded 2844001 embs of 2860802
# Loaded 2844501 embs of 2860802
# Loaded 2845001 embs of 2860802
# Loaded 2845501 embs of 2860802
# Loaded 2846001 embs of 2860802
# Loaded 2846501 embs of 2860802
# Loaded 2847001 embs of 2860802
# Loaded 2847501 embs of 2860802
# Loaded 2848001 embs of 2860802
# Loaded 2848501 embs of 2860802
# Loaded 2849001 embs of 2860802
# Loaded 2849501 embs of 2860802
# Loaded 2850001 embs of 2860802
# Loaded 2850501 embs of 2860802
# Loaded 2851001 embs of 2860802
# Loaded 2851501 embs of 2860802
# Loaded 2852001 embs of 2860802
# Loaded 2852501 embs of 2860802
# Loaded 2853001 embs of 2860802
# Loaded 2853501 embs of 2860802
# Loaded 2854001 embs of 2860802
# Loaded 2854501 embs of 2860802
# Loaded 2855001 embs of 2860802
# Loaded 2855501 embs of 2860802
# Loaded 2856001 embs of 2860802
# Loaded 2856501 embs of 2860802
# Loaded 2857001 embs of 2860802
# Loaded 2857501 embs of 2860802
# Loaded 2858001 embs of 2860802
# Loaded 2858501 embs of 2860802
# Loaded 2859001 embs of 2860802
# Loaded 2859501 embs of 2860802
# Loaded 2860001 embs of 2860802
# Loaded 2860501 embs of 2860802

# %%
len(res)
# Out:
# 114386

# %%
# import pickle

# part = 1
# start = 600000*(part-1)
# end = 600000*(part-0)
# with open(
#     data_path+'/top_sentence_embs/test/'+'test_top_sentences_part_'+str(part)+'.pkl', 
#     'wb') as pickle_file:
#     pickle.dump(res[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# import pickle

# part = 1
# start = 600000*(part-1)
# end = 600000*(part-0)
# with open(
#     data_path+'/top_sentence_embs/validation/'+'validation_top_sentences_part_'+str(part)+'.pkl', 
#     'wb') as pickle_file:
#     pickle.dump(res[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle

part = 1
start = 600000*(part-1)
end = 600000*(part-0)
with open(
    data_path+'/top_sentence_embs/train/'+'train_top_sentences_part_'+str(part)+'.pkl', 
    'wb') as pickle_file:
    pickle.dump(res[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 2
start = 600000*(part-1)
end = 600000*(part-0)
with open(
    data_path+'/top_sentence_embs/train/'+'train_top_sentences_part_'+str(part)+'.pkl', 
    'wb') as pickle_file:
    pickle.dump(res[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 3
start = 600000*(part-1)
end = 600000*(part-0)
with open(
    data_path+'/top_sentence_embs/train/'+'train_top_sentences_part_'+str(part)+'.pkl', 
    'wb') as pickle_file:
    pickle.dump(res[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 4
start = 600000*(part-1)
end = 600000*(part-0)
with open(
    data_path+'/top_sentence_embs/train/'+'train_top_sentences_part_'+str(part)+'.pkl', 
    'wb') as pickle_file:
    pickle.dump(res[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 5
start = 600000*(part-1)
end = 600000*(part-0)
with open(
    data_path+'/top_sentence_embs/train/'+'train_top_sentences_part_'+str(part)+'.pkl', 
    'wb') as pickle_file:
    pickle.dump(res[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)
