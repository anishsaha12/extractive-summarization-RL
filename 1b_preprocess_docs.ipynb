# %%
from datasets import load_dataset, load_from_disk, Dataset
import numpy as np
import pandas as pd
from transformers import RobertaTokenizer, RobertaModel
import torch
from torch.utils.data import TensorDataset, DataLoader

# %%
data_base = 'data'
# data_base = ''

dataset_name = 'cnn_dailymail'

data_path = data_base+'/'+dataset_name

# %%
## set up tokenizer and model
tokenizer = RobertaTokenizer.from_pretrained("roberta-base")
model = RobertaModel.from_pretrained('roberta-base')
# Out:
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
device = torch.device("cuda")
model = model.to(device)
print('model on GPU')
# Out:
# model on GPU

# %%
dataset = load_from_disk(
    data_path+'/sentence_embs_'
)

train_sentence_data = dataset['train']
test_sentence_data = dataset['test']
val_sentence_data = dataset['validation']

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['article_ids', 'attention_mask', 'input_ids'],
#         num_rows: 11358552
#     })
#     validation: Dataset({
#         features: ['article_ids', 'embeddings'],
#         num_rows: 449277
#     })
#     test: Dataset({
#         features: ['article_ids', 'embeddings'],
#         num_rows: 391493
#     })
# })

# %%
train_df = pd.DataFrame(dataset['train'])

# %%
def get_bert_embeddings(batch, method = 'pool'):
    
    train_seq = torch.tensor(batch['input_ids'].to_list()).to(device)
    train_mask = torch.tensor(batch['attention_mask'].to_list()).to(device)

    preds = model(train_seq, train_mask)

    attention_mask = train_mask.cpu()
    base_output = preds.last_hidden_state.detach().cpu()

    if method=='pool':
        # Mean Pool and ignore Padding
        base_output[attention_mask==0, :] = float('nan')
        output_representation = torch.div(torch.nansum(base_output, axis=1), torch.sum(attention_mask==1, axis=1,  keepdim=True))
    elif method=='cls':
        output_representation = base_output[:,0,:]

    output_representation = output_representation.numpy()
    # print('Embeddings Shape:',output_representation.shape)
    
    batch['input_ids'] = batch['input_ids'] #.numpy()
    batch['attention_mask'] = batch['attention_mask'] #.numpy()
    batch['embeddings'] = output_representation.tolist()
    return batch

# %%
batch_size = 40

train_embeddings = []
for i in range(0, len(train_df), batch_size):
    train_embeddings.append(
        get_bert_embeddings(train_df.iloc[i:i+batch_size])['embeddings'].tolist()
    )
    if i//batch_size%100==0:
        print('Completed',i//batch_size,'batches of',len(train_df)//batch_size,'batches')
    if i//batch_size==180000:
        break
# Out:
# <ipython-input-9-5e5d6e5a8444>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch['input_ids'] = batch['input_ids'] #.numpy()
# <ipython-input-9-5e5d6e5a8444>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch['attention_mask'] = batch['attention_mask'] #.numpy()
# <ipython-input-9-5e5d6e5a8444>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   batch['embeddings'] = output_representation.tolist()
# Completed 0 batches of 283963 batches
# Completed 100 batches of 283963 batches
# Completed 200 batches of 283963 batches
# Completed 300 batches of 283963 batches
# Completed 400 batches of 283963 batches
# Completed 500 batches of 283963 batches
# Completed 600 batches of 283963 batches
# Completed 700 batches of 283963 batches
# Completed 800 batches of 283963 batches
# Completed 900 batches of 283963 batches
# Completed 1000 batches of 283963 batches
# Completed 1100 batches of 283963 batches
# Completed 1200 batches of 283963 batches
# Completed 1300 batches of 283963 batches
# Completed 1400 batches of 283963 batches
# Completed 1500 batches of 283963 batches
# Completed 1600 batches of 283963 batches
# Completed 1700 batches of 283963 batches
# Completed 1800 batches of 283963 batches
# Completed 1900 batches of 283963 batches
# Completed 2000 batches of 283963 batches
# Completed 2100 batches of 283963 batches
# Completed 2200 batches of 283963 batches
# Completed 2300 batches of 283963 batches
# Completed 2400 batches of 283963 batches
# Completed 2500 batches of 283963 batches
# Completed 2600 batches of 283963 batches
# Completed 2700 batches of 283963 batches
# Completed 2800 batches of 283963 batches
# Completed 2900 batches of 283963 batches
# Completed 3000 batches of 283963 batches
# Completed 3100 batches of 283963 batches
# Completed 3200 batches of 283963 batches
# Completed 3300 batches of 283963 batches
# Completed 3400 batches of 283963 batches
# Completed 3500 batches of 283963 batches
# Completed 3600 batches of 283963 batches
# Completed 3700 batches of 283963 batches
# Completed 3800 batches of 283963 batches
# Completed 3900 batches of 283963 batches
# Completed 4000 batches of 283963 batches
# Completed 4100 batches of 283963 batches
# Completed 4200 batches of 283963 batches
# Completed 4300 batches of 283963 batches
# Completed 4400 batches of 283963 batches
# Completed 4500 batches of 283963 batches
# Completed 4600 batches of 283963 batches
# Completed 4700 batches of 283963 batches
# Completed 4800 batches of 283963 batches
# Completed 4900 batches of 283963 batches
# Completed 5000 batches of 283963 batches
# Completed 5100 batches of 283963 batches
# Completed 5200 batches of 283963 batches
# Completed 5300 batches of 283963 batches
# Completed 5400 batches of 283963 batches
# Completed 5500 batches of 283963 batches
# Completed 5600 batches of 283963 batches
# Completed 5700 batches of 283963 batches
# Completed 5800 batches of 283963 batches
# Completed 5900 batches of 283963 batches
# Completed 6000 batches of 283963 batches
# Completed 6100 batches of 283963 batches
# Completed 6200 batches of 283963 batches
# Completed 6300 batches of 283963 batches
# Completed 6400 batches of 283963 batches
# Completed 6500 batches of 283963 batches
# Completed 6600 batches of 283963 batches
# Completed 6700 batches of 283963 batches
# Completed 6800 batches of 283963 batches
# Completed 6900 batches of 283963 batches
# Completed 7000 batches of 283963 batches
# Completed 7100 batches of 283963 batches
# Completed 7200 batches of 283963 batches
# Completed 7300 batches of 283963 batches
# Completed 7400 batches of 283963 batches
# Completed 7500 batches of 283963 batches
# Completed 7600 batches of 283963 batches
# Completed 7700 batches of 283963 batches
# Completed 7800 batches of 283963 batches
# Completed 7900 batches of 283963 batches
# Completed 8000 batches of 283963 batches
# Completed 8100 batches of 283963 batches
# Completed 8200 batches of 283963 batches
# Completed 8300 batches of 283963 batches
# Completed 8400 batches of 283963 batches
# Completed 8500 batches of 283963 batches
# Completed 8600 batches of 283963 batches
# Completed 8700 batches of 283963 batches
# Completed 8800 batches of 283963 batches
# Completed 8900 batches of 283963 batches
# Completed 9000 batches of 283963 batches
# Completed 9100 batches of 283963 batches
# Completed 9200 batches of 283963 batches
# Completed 9300 batches of 283963 batches
# Completed 9400 batches of 283963 batches
# Completed 9500 batches of 283963 batches
# Completed 9600 batches of 283963 batches
# Completed 9700 batches of 283963 batches
# Completed 9800 batches of 283963 batches
# Completed 9900 batches of 283963 batches
# Completed 10000 batches of 283963 batches
# Completed 10100 batches of 283963 batches
# Completed 10200 batches of 283963 batches
# Completed 10300 batches of 283963 batches
# Completed 10400 batches of 283963 batches
# Completed 10500 batches of 283963 batches
# Completed 10600 batches of 283963 batches
# Completed 10700 batches of 283963 batches
# Completed 10800 batches of 283963 batches
# Completed 10900 batches of 283963 batches
# Completed 11000 batches of 283963 batches
# Completed 11100 batches of 283963 batches
# Completed 11200 batches of 283963 batches
# Completed 11300 batches of 283963 batches
# Completed 11400 batches of 283963 batches
# Completed 11500 batches of 283963 batches
# Completed 11600 batches of 283963 batches
# Completed 11700 batches of 283963 batches
# Completed 11800 batches of 283963 batches
# Completed 11900 batches of 283963 batches
# Completed 12000 batches of 283963 batches
# Completed 12100 batches of 283963 batches
# Completed 12200 batches of 283963 batches
# Completed 12300 batches of 283963 batches
# Completed 12400 batches of 283963 batches
# Completed 12500 batches of 283963 batches
# Completed 12600 batches of 283963 batches
# Completed 12700 batches of 283963 batches
# Completed 12800 batches of 283963 batches
# Completed 12900 batches of 283963 batches
# Completed 13000 batches of 283963 batches
# Completed 13100 batches of 283963 batches
# Completed 13200 batches of 283963 batches
# Completed 13300 batches of 283963 batches
# Completed 13400 batches of 283963 batches
# Completed 13500 batches of 283963 batches
# Completed 13600 batches of 283963 batches
# Completed 13700 batches of 283963 batches
# Completed 13800 batches of 283963 batches
# Completed 13900 batches of 283963 batches
# Completed 14000 batches of 283963 batches
# Completed 14100 batches of 283963 batches
# Completed 14200 batches of 283963 batches
# Completed 14300 batches of 283963 batches
# Completed 14400 batches of 283963 batches
# Completed 14500 batches of 283963 batches
# Completed 14600 batches of 283963 batches
# Completed 14700 batches of 283963 batches
# Completed 14800 batches of 283963 batches
# Completed 14900 batches of 283963 batches
# Completed 15000 batches of 283963 batches
# Completed 15100 batches of 283963 batches
# Completed 15200 batches of 283963 batches
# Completed 15300 batches of 283963 batches
# Completed 15400 batches of 283963 batches
# Completed 15500 batches of 283963 batches
# Completed 15600 batches of 283963 batches
# Completed 15700 batches of 283963 batches
# Completed 15800 batches of 283963 batches
# Completed 15900 batches of 283963 batches
# Completed 16000 batches of 283963 batches
# Completed 16100 batches of 283963 batches
# Completed 16200 batches of 283963 batches
# Completed 16300 batches of 283963 batches
# Completed 16400 batches of 283963 batches
# Completed 16500 batches of 283963 batches
# Completed 16600 batches of 283963 batches
# Completed 16700 batches of 283963 batches
# Completed 16800 batches of 283963 batches
# Completed 16900 batches of 283963 batches
# Completed 17000 batches of 283963 batches
# Completed 17100 batches of 283963 batches
# Completed 17200 batches of 283963 batches
# Completed 17300 batches of 283963 batches
# Completed 17400 batches of 283963 batches
# Completed 17500 batches of 283963 batches
# Completed 17600 batches of 283963 batches
# Completed 17700 batches of 283963 batches
# Completed 17800 batches of 283963 batches
# Completed 17900 batches of 283963 batches
# Completed 18000 batches of 283963 batches
# Completed 18100 batches of 283963 batches
# Completed 18200 batches of 283963 batches
# Completed 18300 batches of 283963 batches
# Completed 18400 batches of 283963 batches
# Completed 18500 batches of 283963 batches
# Completed 18600 batches of 283963 batches
# Completed 18700 batches of 283963 batches
# Completed 19200 batches of 283963 batches
# Completed 19300 batches of 283963 batches
# Completed 19400 batches of 283963 batches
# Completed 19500 batches of 283963 batches
# Completed 19600 batches of 283963 batches
# Completed 19700 batches of 283963 batches
# Completed 19800 batches of 283963 batches
# Completed 19900 batches of 283963 batches
# Completed 20000 batches of 283963 batches
# Completed 20100 batches of 283963 batches
# Completed 20200 batches of 283963 batches
# Completed 20300 batches of 283963 batches
# Completed 20400 batches of 283963 batches
# Completed 20500 batches of 283963 batches
# Completed 20600 batches of 283963 batches
# Completed 20700 batches of 283963 batches
# Completed 21200 batches of 283963 batches
# Completed 21300 batches of 283963 batches
# Completed 21400 batches of 283963 batches
# Completed 21500 batches of 283963 batches
# Completed 21600 batches of 283963 batches
# Completed 21700 batches of 283963 batches
# Completed 21800 batches of 283963 batches
# Completed 21900 batches of 283963 batches
# Completed 22000 batches of 283963 batches
# Completed 22100 batches of 283963 batches
# Completed 22200 batches of 283963 batches
# Completed 22300 batches of 283963 batches
# Completed 22400 batches of 283963 batches
# Completed 22500 batches of 283963 batches
# Completed 22600 batches of 283963 batches
# Completed 22700 batches of 283963 batches
# Completed 22800 batches of 283963 batches
# Completed 22900 batches of 283963 batches
# Completed 23000 batches of 283963 batches
# Completed 23100 batches of 283963 batches
# Completed 23200 batches of 283963 batches
# Completed 23300 batches of 283963 batches
# Completed 23400 batches of 283963 batches
# Completed 23500 batches of 283963 batches
# Completed 23600 batches of 283963 batches
# Completed 23700 batches of 283963 batches
# Completed 23800 batches of 283963 batches
# Completed 23900 batches of 283963 batches
# Completed 24000 batches of 283963 batches
# Completed 24100 batches of 283963 batches
# Completed 24200 batches of 283963 batches
# Completed 24300 batches of 283963 batches
# Completed 24400 batches of 283963 batches
# Completed 24500 batches of 283963 batches
# Completed 24600 batches of 283963 batches
# Completed 24700 batches of 283963 batches
# Completed 24800 batches of 283963 batches
# Completed 24900 batches of 283963 batches
# Completed 25000 batches of 283963 batches
# Completed 25100 batches of 283963 batches
# Completed 25200 batches of 283963 batches
# Completed 25300 batches of 283963 batches
# Completed 25400 batches of 283963 batches
# Completed 25500 batches of 283963 batches
# Completed 25600 batches of 283963 batches
# Completed 25700 batches of 283963 batches
# Completed 25800 batches of 283963 batches
# Completed 25900 batches of 283963 batches
# Completed 26000 batches of 283963 batches
# Completed 26100 batches of 283963 batches
# Completed 26200 batches of 283963 batches
# Completed 26300 batches of 283963 batches
# Completed 26400 batches of 283963 batches
# Completed 26500 batches of 283963 batches
# Completed 26600 batches of 283963 batches
# Completed 26700 batches of 283963 batches
# Completed 26800 batches of 283963 batches
# Completed 26900 batches of 283963 batches
# Completed 27000 batches of 283963 batches
# Completed 27100 batches of 283963 batches
# Completed 27200 batches of 283963 batches
# Completed 27300 batches of 283963 batches
# Completed 27400 batches of 283963 batches
# Completed 27500 batches of 283963 batches
# Completed 27600 batches of 283963 batches
# Completed 27700 batches of 283963 batches
# Completed 27800 batches of 283963 batches
# Completed 27900 batches of 283963 batches
# Completed 28000 batches of 283963 batches
# Completed 28100 batches of 283963 batches
# Completed 28200 batches of 283963 batches
# Completed 28300 batches of 283963 batches
# Completed 28400 batches of 283963 batches
# Completed 28500 batches of 283963 batches
# Completed 28600 batches of 283963 batches
# Completed 28700 batches of 283963 batches
# Completed 28800 batches of 283963 batches
# Completed 28900 batches of 283963 batches
# Completed 29000 batches of 283963 batches
# Completed 29100 batches of 283963 batches
# Completed 29200 batches of 283963 batches
# Completed 29300 batches of 283963 batches
# Completed 29400 batches of 283963 batches
# Completed 29500 batches of 283963 batches
# Completed 29600 batches of 283963 batches
# Completed 29700 batches of 283963 batches
# Completed 29800 batches of 283963 batches
# Completed 29900 batches of 283963 batches
# Completed 30000 batches of 283963 batches
# Completed 30100 batches of 283963 batches
# Completed 30200 batches of 283963 batches
# Completed 30300 batches of 283963 batches
# Completed 30400 batches of 283963 batches
# Completed 30500 batches of 283963 batches
# Completed 30600 batches of 283963 batches
# Completed 30700 batches of 283963 batches
# Completed 30800 batches of 283963 batches
# Completed 30900 batches of 283963 batches
# Completed 31000 batches of 283963 batches
# Completed 31100 batches of 283963 batches
# Completed 31200 batches of 283963 batches
# Completed 31300 batches of 283963 batches
# Completed 31400 batches of 283963 batches
# Completed 31500 batches of 283963 batches
# Completed 31600 batches of 283963 batches
# Completed 31700 batches of 283963 batches
# Completed 31800 batches of 283963 batches
# Completed 31900 batches of 283963 batches
# Completed 32000 batches of 283963 batches
# Completed 32100 batches of 283963 batches
# Completed 32200 batches of 283963 batches
# Completed 32300 batches of 283963 batches
# Completed 32400 batches of 283963 batches
# Completed 32500 batches of 283963 batches
# Completed 32600 batches of 283963 batches
# Completed 32700 batches of 283963 batches
# Completed 32800 batches of 283963 batches
# Completed 32900 batches of 283963 batches
# Completed 33000 batches of 283963 batches
# Completed 33100 batches of 283963 batches
# Completed 33200 batches of 283963 batches
# Completed 33300 batches of 283963 batches
# Completed 33400 batches of 283963 batches
# Completed 33500 batches of 283963 batches
# Completed 33600 batches of 283963 batches
# Completed 33700 batches of 283963 batches
# Completed 33800 batches of 283963 batches
# Completed 33900 batches of 283963 batches
# Completed 34000 batches of 283963 batches
# Completed 34100 batches of 283963 batches
# Completed 34200 batches of 283963 batches
# Completed 34300 batches of 283963 batches
# Completed 34400 batches of 283963 batches
# Completed 34500 batches of 283963 batches
# Completed 34600 batches of 283963 batches
# Completed 34700 batches of 283963 batches
# Completed 34800 batches of 283963 batches
# Completed 34900 batches of 283963 batches
# Completed 35000 batches of 283963 batches
# Completed 35100 batches of 283963 batches
# Completed 35200 batches of 283963 batches
# Completed 35300 batches of 283963 batches
# Completed 35400 batches of 283963 batches
# Completed 35500 batches of 283963 batches
# Completed 35600 batches of 283963 batches
# Completed 35700 batches of 283963 batches
# Completed 35800 batches of 283963 batches
# Completed 35900 batches of 283963 batches
# Completed 36000 batches of 283963 batches
# Completed 36100 batches of 283963 batches
# Completed 36200 batches of 283963 batches
# Completed 36300 batches of 283963 batches
# Completed 36400 batches of 283963 batches
# Completed 36500 batches of 283963 batches
# Completed 36600 batches of 283963 batches
# Completed 36700 batches of 283963 batches
# Completed 36800 batches of 283963 batches
# Completed 36900 batches of 283963 batches
# Completed 37000 batches of 283963 batches
# Completed 37100 batches of 283963 batches
# Completed 37200 batches of 283963 batches
# Completed 37300 batches of 283963 batches
# Completed 37400 batches of 283963 batches
# Completed 37500 batches of 283963 batches
# Completed 37600 batches of 283963 batches
# Completed 37700 batches of 283963 batches
# Completed 37800 batches of 283963 batches
# Completed 37900 batches of 283963 batches
# Completed 38000 batches of 283963 batches
# Completed 38100 batches of 283963 batches
# Completed 38200 batches of 283963 batches
# Completed 38300 batches of 283963 batches
# Completed 38400 batches of 283963 batches
# Completed 38500 batches of 283963 batches
# Completed 38600 batches of 283963 batches
# Completed 38700 batches of 283963 batches
# Completed 38800 batches of 283963 batches
# Completed 38900 batches of 283963 batches
# Completed 39000 batches of 283963 batches
# Completed 39100 batches of 283963 batches
# Completed 39200 batches of 283963 batches
# Completed 39300 batches of 283963 batches
# Completed 39400 batches of 283963 batches
# Completed 39500 batches of 283963 batches
# Completed 39600 batches of 283963 batches
# Completed 39700 batches of 283963 batches
# Completed 39800 batches of 283963 batches
# Completed 39900 batches of 283963 batches
# Completed 40000 batches of 283963 batches
# Completed 40100 batches of 283963 batches
# Completed 40200 batches of 283963 batches
# Completed 40300 batches of 283963 batches
# Completed 40400 batches of 283963 batches
# Completed 40500 batches of 283963 batches
# Completed 40600 batches of 283963 batches
# Completed 40700 batches of 283963 batches
# Completed 40800 batches of 283963 batches
# Completed 40900 batches of 283963 batches
# Completed 41000 batches of 283963 batches
# Completed 41100 batches of 283963 batches
# Completed 41200 batches of 283963 batches
# Completed 41300 batches of 283963 batches
# Completed 41400 batches of 283963 batches
# Completed 41500 batches of 283963 batches
# Completed 41600 batches of 283963 batches
# Completed 41700 batches of 283963 batches
# Completed 41800 batches of 283963 batches
# Completed 41900 batches of 283963 batches
# Completed 42000 batches of 283963 batches
# Completed 42100 batches of 283963 batches
# Completed 42200 batches of 283963 batches
# Completed 42300 batches of 283963 batches
# Completed 42400 batches of 283963 batches
# Completed 42500 batches of 283963 batches
# Completed 42600 batches of 283963 batches
# Completed 42700 batches of 283963 batches
# Completed 42800 batches of 283963 batches
# Completed 42900 batches of 283963 batches
# Completed 43000 batches of 283963 batches
# Completed 43100 batches of 283963 batches
# Completed 43200 batches of 283963 batches
# Completed 43300 batches of 283963 batches
# Completed 43400 batches of 283963 batches
# Completed 43500 batches of 283963 batches
# Completed 43600 batches of 283963 batches
# Completed 43700 batches of 283963 batches
# Completed 43800 batches of 283963 batches
# Completed 43900 batches of 283963 batches
# Completed 44000 batches of 283963 batches
# Completed 44100 batches of 283963 batches
# Completed 44200 batches of 283963 batches
# Completed 44300 batches of 283963 batches
# Completed 44400 batches of 283963 batches
# Completed 44500 batches of 283963 batches
# Completed 44600 batches of 283963 batches
# Completed 44700 batches of 283963 batches
# Completed 44800 batches of 283963 batches
# Completed 44900 batches of 283963 batches
# Completed 45000 batches of 283963 batches
# Completed 45100 batches of 283963 batches
# Completed 45200 batches of 283963 batches
# Completed 45300 batches of 283963 batches
# Completed 45400 batches of 283963 batches
# Completed 45500 batches of 283963 batches
# Completed 45600 batches of 283963 batches
# Completed 45700 batches of 283963 batches
# Completed 45800 batches of 283963 batches
# Completed 45900 batches of 283963 batches
# Completed 46000 batches of 283963 batches
# Completed 46100 batches of 283963 batches
# Completed 46200 batches of 283963 batches
# Completed 46300 batches of 283963 batches
# Completed 46400 batches of 283963 batches
# Completed 46500 batches of 283963 batches
# Completed 46600 batches of 283963 batches
# Completed 46700 batches of 283963 batches
# Completed 46800 batches of 283963 batches
# Completed 46900 batches of 283963 batches
# Completed 47000 batches of 283963 batches
# Completed 47100 batches of 283963 batches
# Completed 47200 batches of 283963 batches
# Completed 47300 batches of 283963 batches
# Completed 47400 batches of 283963 batches
# Completed 47500 batches of 283963 batches
# Completed 47600 batches of 283963 batches
# Completed 47700 batches of 283963 batches
# Completed 47800 batches of 283963 batches
# Completed 47900 batches of 283963 batches
# Completed 48000 batches of 283963 batches
# Completed 48100 batches of 283963 batches
# Completed 48200 batches of 283963 batches
# Completed 48300 batches of 283963 batches
# Completed 48400 batches of 283963 batches
# Completed 48500 batches of 283963 batches
# Completed 48600 batches of 283963 batches
# Completed 48700 batches of 283963 batches
# Completed 48800 batches of 283963 batches
# Completed 48900 batches of 283963 batches
# Completed 49000 batches of 283963 batches
# Completed 49100 batches of 283963 batches
# Completed 49200 batches of 283963 batches
# Completed 49300 batches of 283963 batches
# Completed 49400 batches of 283963 batches
# Completed 49500 batches of 283963 batches
# Completed 49600 batches of 283963 batches
# Completed 49700 batches of 283963 batches
# Completed 49800 batches of 283963 batches
# Completed 49900 batches of 283963 batches
# Completed 50000 batches of 283963 batches
# Completed 50100 batches of 283963 batches
# Completed 50200 batches of 283963 batches
# Completed 50300 batches of 283963 batches
# Completed 50400 batches of 283963 batches
# Completed 50500 batches of 283963 batches
# Completed 50600 batches of 283963 batches
# Completed 50700 batches of 283963 batches
# Completed 50800 batches of 283963 batches
# Completed 50900 batches of 283963 batches
# Completed 51000 batches of 283963 batches
# Completed 51100 batches of 283963 batches
# Completed 51200 batches of 283963 batches
# Completed 51300 batches of 283963 batches
# Completed 51400 batches of 283963 batches
# Completed 51500 batches of 283963 batches
# Completed 51600 batches of 283963 batches
# Completed 51700 batches of 283963 batches
# Completed 51800 batches of 283963 batches
# Completed 51900 batches of 283963 batches
# Completed 52000 batches of 283963 batches
# Completed 52100 batches of 283963 batches
# Completed 52200 batches of 283963 batches
# Completed 52300 batches of 283963 batches
# Completed 52400 batches of 283963 batches
# Completed 52500 batches of 283963 batches
# Completed 52600 batches of 283963 batches
# Completed 52700 batches of 283963 batches
# Completed 52800 batches of 283963 batches
# Completed 52900 batches of 283963 batches
# Completed 53000 batches of 283963 batches
# Completed 53100 batches of 283963 batches
# Completed 53200 batches of 283963 batches
# Completed 53300 batches of 283963 batches
# Completed 53400 batches of 283963 batches
# Completed 53500 batches of 283963 batches
# Completed 53600 batches of 283963 batches
# Completed 53700 batches of 283963 batches
# Completed 53800 batches of 283963 batches
# Completed 53900 batches of 283963 batches
# Completed 54000 batches of 283963 batches
# Completed 54100 batches of 283963 batches
# Completed 54200 batches of 283963 batches
# Completed 54300 batches of 283963 batches
# Completed 54400 batches of 283963 batches
# Completed 54500 batches of 283963 batches
# Completed 54600 batches of 283963 batches
# Completed 54700 batches of 283963 batches
# Completed 54800 batches of 283963 batches
# Completed 54900 batches of 283963 batches
# Completed 55000 batches of 283963 batches
# Completed 55100 batches of 283963 batches
# Completed 55200 batches of 283963 batches
# Completed 55300 batches of 283963 batches
# Completed 55400 batches of 283963 batches
# Completed 55500 batches of 283963 batches
# Completed 55600 batches of 283963 batches
# Completed 55700 batches of 283963 batches
# Completed 55800 batches of 283963 batches
# Completed 55900 batches of 283963 batches
# Completed 56000 batches of 283963 batches
# Completed 56100 batches of 283963 batches
# Completed 56200 batches of 283963 batches
# Completed 56300 batches of 283963 batches
# Completed 56400 batches of 283963 batches
# Completed 56500 batches of 283963 batches
# Completed 56600 batches of 283963 batches
# Completed 56700 batches of 283963 batches
# Completed 56800 batches of 283963 batches
# Completed 56900 batches of 283963 batches
# Completed 57000 batches of 283963 batches
# Completed 57100 batches of 283963 batches
# Completed 57200 batches of 283963 batches
# Completed 57300 batches of 283963 batches
# Completed 57400 batches of 283963 batches
# Completed 57500 batches of 283963 batches
# Completed 57600 batches of 283963 batches
# Completed 57700 batches of 283963 batches
# Completed 57800 batches of 283963 batches
# Completed 57900 batches of 283963 batches
# Completed 58000 batches of 283963 batches
# Completed 58100 batches of 283963 batches
# Completed 58200 batches of 283963 batches
# Completed 58300 batches of 283963 batches
# Completed 58400 batches of 283963 batches
# Completed 58500 batches of 283963 batches
# Completed 58600 batches of 283963 batches
# Completed 58700 batches of 283963 batches
# Completed 58800 batches of 283963 batches
# Completed 58900 batches of 283963 batches
# Completed 59000 batches of 283963 batches
# Completed 59100 batches of 283963 batches
# Completed 59200 batches of 283963 batches
# Completed 59300 batches of 283963 batches
# Completed 59400 batches of 283963 batches
# Completed 59500 batches of 283963 batches
# Completed 59600 batches of 283963 batches
# Completed 59700 batches of 283963 batches
# Completed 59800 batches of 283963 batches
# Completed 59900 batches of 283963 batches
# Completed 60000 batches of 283963 batches
# Completed 60100 batches of 283963 batches
# Completed 60200 batches of 283963 batches
# Completed 60300 batches of 283963 batches
# Completed 60400 batches of 283963 batches
# Completed 60500 batches of 283963 batches
# Completed 60600 batches of 283963 batches
# Completed 60700 batches of 283963 batches

# %%
len(train_embeddings), i
# Out:
# (180001, 7200000)

# %%
# batch_size = 40

# new_i = 7200000
# train_embeddings = []

# for i in range(new_i, len(train_df), batch_size):
#     train_embeddings.append(
#         get_bert_embeddings(train_df.iloc[i:i+batch_size])['embeddings'].tolist()
#     )
#     if i//batch_size%100==0:
#         print('Completed',i//batch_size,'batches of',len(train_df)//batch_size,'batches')

# %%
len(train_embeddings), i, i//batch_size
# Out:
# (103964, 11358520, 283963)

# %%
import pickle

# %%
part = 1
start = 20000*(part-1)
end = 20000*(part)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 2
start = 20000*(part-1)
end = 20000*(part)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 3
start = 20000*(part-1)
end = 20000*(part)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 4
start = 20000*(part-4)
end = 20000*(part-3)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 5
start = 20000*(part-4)
end = 20000*(part-3)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 6
start = 20000*(part-4)
end = 20000*(part-3)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 7
start = 20000*(part-4)
end = 20000*(part-3)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 8
start = 20000*(part-4)
end = 20000*(part-3)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 9
start = 20000*(part-4)
end = 20000*(part-3)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
part = 10
start = 20000*(part-10)
end = 20000*(part-9)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 11
start = 20000*(part-10)
end = 20000*(part-9)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 12
start = 20000*(part-10)
end = 20000*(part-9)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 13
start = 20000*(part-10)
end = 20000*(part-9)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 14
start = 20000*(part-10)
end = 20000*(part-9)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

part = 15
start = 20000*(part-10)
end = 20000*(part-9)
with open('train_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(train_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)

# %%
train_embeddings = np.vstack(train_embeddings)

# %%
dataset = load_from_disk(
    'sentence_embs_'
)

test_sentence_data = dataset['test']
val_sentence_data = dataset['validation']

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['article_ids', 'attention_mask', 'input_ids'],
#         num_rows: 11358552
#     })
#     validation: Dataset({
#         features: ['article_ids', 'embeddings'],
#         num_rows: 449277
#     })
#     test: Dataset({
#         features: ['article_ids', 'embeddings'],
#         num_rows: 391493
#     })
# })

# %%
test_df = pd.DataFrame(dataset['test'])

# %%
batch_size = 40

test_embeddings = []
for i in range(0, test_sentence_data.num_rows, batch_size):
    test_embeddings.append(
        test_df.iloc[i:i+batch_size]['embeddings'].tolist()
    )
    if i//batch_size%100==0:
        print('Loaded',i//batch_size,'batches of',test_sentence_data.num_rows//batch_size,'batches')
# Out:
# Loaded 0 batches of 9787 batches
# Loaded 100 batches of 9787 batches
# Loaded 200 batches of 9787 batches
# Loaded 300 batches of 9787 batches
# Loaded 400 batches of 9787 batches
# Loaded 500 batches of 9787 batches
# Loaded 600 batches of 9787 batches
# Loaded 700 batches of 9787 batches
# Loaded 800 batches of 9787 batches
# Loaded 900 batches of 9787 batches
# Loaded 1000 batches of 9787 batches
# Loaded 1100 batches of 9787 batches
# Loaded 1200 batches of 9787 batches
# Loaded 1300 batches of 9787 batches
# Loaded 1400 batches of 9787 batches
# Loaded 1500 batches of 9787 batches
# Loaded 1600 batches of 9787 batches
# Loaded 1700 batches of 9787 batches
# Loaded 1800 batches of 9787 batches
# Loaded 1900 batches of 9787 batches
# Loaded 2000 batches of 9787 batches
# Loaded 2100 batches of 9787 batches
# Loaded 2200 batches of 9787 batches
# Loaded 2300 batches of 9787 batches
# Loaded 2400 batches of 9787 batches
# Loaded 2500 batches of 9787 batches
# Loaded 2600 batches of 9787 batches
# Loaded 2700 batches of 9787 batches
# Loaded 2800 batches of 9787 batches
# Loaded 2900 batches of 9787 batches
# Loaded 3000 batches of 9787 batches
# Loaded 3100 batches of 9787 batches
# Loaded 3200 batches of 9787 batches
# Loaded 3300 batches of 9787 batches
# Loaded 3400 batches of 9787 batches
# Loaded 3500 batches of 9787 batches
# Loaded 3600 batches of 9787 batches
# Loaded 3700 batches of 9787 batches
# Loaded 3800 batches of 9787 batches
# Loaded 3900 batches of 9787 batches
# Loaded 4000 batches of 9787 batches
# Loaded 4100 batches of 9787 batches
# Loaded 4200 batches of 9787 batches
# Loaded 4300 batches of 9787 batches
# Loaded 4400 batches of 9787 batches
# Loaded 4500 batches of 9787 batches
# Loaded 4600 batches of 9787 batches
# Loaded 4700 batches of 9787 batches
# Loaded 4800 batches of 9787 batches
# Loaded 4900 batches of 9787 batches
# Loaded 5000 batches of 9787 batches
# Loaded 5100 batches of 9787 batches
# Loaded 5200 batches of 9787 batches
# Loaded 5300 batches of 9787 batches
# Loaded 5400 batches of 9787 batches
# Loaded 5500 batches of 9787 batches
# Loaded 5600 batches of 9787 batches
# Loaded 5700 batches of 9787 batches
# Loaded 5800 batches of 9787 batches
# Loaded 5900 batches of 9787 batches
# Loaded 6000 batches of 9787 batches
# Loaded 6100 batches of 9787 batches
# Loaded 6200 batches of 9787 batches
# Loaded 6300 batches of 9787 batches
# Loaded 6400 batches of 9787 batches
# Loaded 6500 batches of 9787 batches
# Loaded 6600 batches of 9787 batches
# Loaded 6700 batches of 9787 batches
# Loaded 6800 batches of 9787 batches
# Loaded 6900 batches of 9787 batches
# Loaded 7000 batches of 9787 batches
# Loaded 7100 batches of 9787 batches
# Loaded 7200 batches of 9787 batches
# Loaded 7300 batches of 9787 batches
# Loaded 7400 batches of 9787 batches
# Loaded 7500 batches of 9787 batches
# Loaded 7600 batches of 9787 batches
# Loaded 7700 batches of 9787 batches
# Loaded 7800 batches of 9787 batches
# Loaded 7900 batches of 9787 batches
# Loaded 8000 batches of 9787 batches
# Loaded 8100 batches of 9787 batches
# Loaded 8200 batches of 9787 batches
# Loaded 8300 batches of 9787 batches
# Loaded 8400 batches of 9787 batches
# Loaded 8500 batches of 9787 batches
# Loaded 8600 batches of 9787 batches
# Loaded 8700 batches of 9787 batches
# Loaded 8800 batches of 9787 batches
# Loaded 8900 batches of 9787 batches
# Loaded 9000 batches of 9787 batches
# Loaded 9100 batches of 9787 batches
# Loaded 9200 batches of 9787 batches
# Loaded 9300 batches of 9787 batches
# Loaded 9400 batches of 9787 batches
# Loaded 9500 batches of 9787 batches
# Loaded 9600 batches of 9787 batches
# Loaded 9700 batches of 9787 batches

# %%
len(test_embeddings)
# Out:
# 9788

# %%
import pickle

part = 1
start = 20000*(part-1)
end = 20000*(part)
with open('test_part_'+str(part)+'.pkl', 'wb') as pickle_file:
    pickle.dump(test_embeddings[start:end], pickle_file, protocol=pickle.HIGHEST_PROTOCOL)
